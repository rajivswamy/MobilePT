# %%
# General imports
import cv2
import mediapipe as mp
import numpy as np
import os
import sys
from datetime import datetime, date
import time
import uuid
import seaborn as sns
import matplotlib.pyplot as plt
import pprint


# data processing and visualization helper functions
from processing import process_image, process_video
from data_acquisition import capture_session
from visualization import plot_ROM_dtw_comparisons, calc_DTW_joints_metrics, create_3D_keypoints_video, plot_ex_animation


# Request handling and data payload packaging
from django.core.serializers.json import DjangoJSONEncoder
import json
import requests

# DTW imports
from dtw import *
# Out:
# Importing the dtw module. When using in academic works please cite:
#   T. Giorgino. Computing and Visualizing Dynamic Time Warping Alignments in R: The dtw Package.
#   J. Stat. Soft., doi:10.18637/jss.v031.i07.

# %% [markdown]
# # Per Exercise DTW Testing

# %%
EXERCISE = 'LEG_RAISE'
OUTPUT_FOLDER = './captures/'

# %% [markdown]
# ### Create Reference

# %%
date_str = datetime.now().isoformat()
name = f"{EXERCISE}_reference_{date_str}"
date = datetime(2022, 12, 1)
target_reps = 4

# Capture video recording and image
image_path, video_path = capture_session(name, 10, 12, base_dir='./captures/')
# Out:
# Entering Video Loop

# %%
# Process image and video
flag, image_output = process_image(image_path)
if not flag:
    assert("Error")

flag, video_output = process_video(video_path)
if not flag:
    assert("Error")

# Prep payload
payload = dict(
    exercise=EXERCISE,
    target_reps= target_reps,
    name = name,
    date=date,
    pose_keypoints = image_output,
    keypoints_sequence = video_output
)

ref_url = 'http://127.0.0.1:8000/api/v1/reference_sessions/'

# Send requests to REST API Endpoint
r = requests.post(ref_url, data=json.dumps(payload, cls=DjangoJSONEncoder), headers={'Content-Type': 'application/json'})
r.raise_for_status()

reference_data = r.json()

print(reference_data['id'])
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# de0e590d-e485-43ad-8034-24094d569345

# %% [markdown]
# # Send Test Exercise Sessions

# %%
def execute_exercise_session(exercise, name, ref_id, target_reps, image_path, video_path):
    date = datetime(2022, 12, 1)
    
    # Process image and video
    flag, image_output = process_image(image_path)
    if not flag:
        assert("Error")

    flag, video_output = process_video(video_path)
    if not flag:
        assert("Error")

    # Prep payload
    payload = dict(
        exercise=exercise,
        target_reps= target_reps,
        sets=1,
        name = name,
        date=date,
        reference=ref_id,
        pose_keypoints = image_output,
        keypoints_sequence = video_output
    )

    ex_url = 'http://127.0.0.1:8000/api/v1/exercise_sessions/'

    # Send requests to REST API Endpoint
    r = requests.post(ex_url, data=json.dumps(payload, cls=DjangoJSONEncoder), headers={'Content-Type': 'application/json'})
    r.raise_for_status()

    return r.json()

# %% [markdown]
# Initialize list to hold pairs of ex and ref data

# %%
pairs = []
ref_id = 'de0e590d-e485-43ad-8034-24094d569345'
target_reps = 4

# %% [markdown]
# ### Session 1: Similar to Reference

# %%
date_str = datetime.now().isoformat()
name = f"{EXERCISE}_{'base_session'}_{date_str}"
target_reps = 4

# Capture video recording and image
image_path, video_path = capture_session(name,10,12, base_dir='./captures/')
# Out:
# Entering Video Loop

# %%
ex_data = execute_exercise_session(EXERCISE, name, ref_id, target_reps, image_path, video_path)
# pairs.append((ex_data, reference_data))

# %% [markdown]
# ### Session 2: Diff Angle from Session 1

# %%
date_str = datetime.now().isoformat()
name = f"{EXERCISE}_{'diff_angle'}_{date_str}"
target_reps = 4

# Capture video recording and image
image_path, video_path = capture_session(name,10,12, base_dir='./captures/')
# Out:
# Entering Video Loop

# %%
ex_data = execute_exercise_session(EXERCISE, name, ref_id, target_reps, image_path, video_path)
# pairs.append((ex_data, reference_data))

# %% [markdown]
# ### Session 3: Static Pose

# %%
date_str = datetime.now().isoformat()
name = f"{EXERCISE}_{'static_pose'}_{date_str}"
target_reps = 4

# Capture video recording and image
image_path, video_path = capture_session(name,10,12, base_dir='./captures/')
# Out:
# Entering Video Loop

# %%
ex_data = execute_exercise_session(EXERCISE, name, ref_id, target_reps, image_path, video_path)
# pairs.append((ex_data, reference_data))

# %% [markdown]
# ### Session 4: Pauses

# %%
date_str = datetime.now().isoformat()
name = f"{EXERCISE}_{'pauses'}_{date_str}"
target_reps = 4

# Capture video recording and image
image_path, video_path = capture_session(name,10,20, base_dir='./captures/')
# Out:
# Entering Video Loop

# %%
# image_path = './captures/SQUAT_pauses_2023-01-10T02:34:35.626182.jpg'
# video_path = './captures/SQUAT_pauses_2023-01-10T02:34:35.626182.m4v'

ex_data = execute_exercise_session(EXERCISE, name, ref_id, target_reps, image_path, video_path)
# pairs.append((ex_data, reference_data))

# %% [markdown]
# ### Session 5: Half reps

# %%
date_str = datetime.now().isoformat()
name = f"{EXERCISE}_{'half_reps'}_{date_str}"
target_reps = 4

# Capture video recording and image
image_path, video_path = capture_session(name,10,12, base_dir='./captures/')
# Out:
# Entering Video Loop

# %%
ex_data = execute_exercise_session(EXERCISE, name, ref_id, target_reps, image_path, video_path)
# pairs.append((ex_data, reference_data))

# %% [markdown]
# Get data

# %%
# Get all exercise data 
ex_url = 'http://127.0.0.1:8000/api/v1/exercise_sessions/'
ref_url = 'http://127.0.0.1:8000/api/v1/reference_sessions/'

pp = pprint.PrettyPrinter(indent=4, sort_dicts=True)

r = requests.get(ex_url)

ex_sessions = r.json()

pairs = []

for ex_session in ex_sessions:
    id  = ex_session['reference']

    if id == 'de0e590d-e485-43ad-8034-24094d569345':
        r = requests.get(ref_url+ref_id)
        ref_data = r.json()
        pairs.append((ex_session, ref_data))

# %% [markdown]
# Write raw data to JSON file

# %%
date_str = datetime.now().isoformat()

path = os.path.join('./DTW_data_archive', f"{EXERCISE}_DTW_pairs_{date_str}.json")

with open(path, 'w') as f:
    json.dump(pairs, f, indent=4)

# %% [markdown]
# # Analyze Data

# %% [markdown]
# basically get a dataframe output

# %%
pp = pprint.PrettyPrinter(indent=4, sort_dicts=True)

for pair in pairs:
    ex_data, ref_data = pair
    pp.pprint(ex_data['name'])
    pp.pprint(ex_data['analytics']['DTW'])
# Out:
# 'LEG_RAISE_base_session_2023-01-10T14:37:19.476495'
# {   'joint_angles_agg': {   'accuracy': 0.9040023482071047,
#                             'dist': 7879.48725916085,
#                             'normalized_dist': 11.81332422662796,
#                             'path_len': 513},
#     'joint_angles_agg_joi': {   'accuracy': 0.8687139738435261,
#                                 'dist': 2709.743579869622,
#                                 'normalized_dist': 4.06258407776555,
#                                 'path_len': 516},
#     'joint_angles_agg_norm': {   'accuracy': 0.9029807884890347,
#                                  'dist': 8134.090693079331,
#                                  'normalized_dist': 12.195038520358818,
#                                  'path_len': 524},
#     'joint_angles_agg_norm_joi': {   'accuracy': 0.8439787661164688,
#                                      'dist': 3357.5769531735923,
#                                      'normalized_dist': 5.033848505507635,
#                                      'path_len': 538},
#     'joint_angles_indiv': {   'accuracy': 0.9401420766525976,
#                               'dist': 6388.037579634774,
#                               'joint_alignments': {   'L_ELBOW': {   'dist': 1028.6296135588448,
#                                                                      'normalized_dist': 1.5421733336714314,
#                                                                      'path_len': 514},
#                                                       'L_HIP': {   'dist': 1144.5478023162545,
#                                                                    'normalized_dist': 1.715963721613575,
#                                                                    'path_len': 510},
#                                                       'L_KNEE': {   'dist': 437.94442013648734,
#                                                                     'normalized_dist': 0.6565883360367126,
#                                                                     'path_len': 544},
#                                                       'L_SHOULDER': {   'dist': 400.5288826243483,
#                                                                         'normalized_dist': 0.6004930773978235,
#                                                                         'path_len': 529},
#                                                       'R_ELBOW': {   'dist': 797.6514005025286,
#                                                                      'normalized_dist': 1.1958791611732065,
#                                                                      'path_len': 563},
#                                                       'R_HIP': {   'dist': 895.9389620729008,
#                                                                    'normalized_dist': 1.3432368246970028,
#                                                                    'path_len': 492},
#                                                       'R_KNEE': {   'dist': 597.541027559955,
#                                                                     'normalized_dist': 0.8958636095351649,
#                                                                     'path_len': 521},
#                                                       'R_SHOULDER': {   'dist': 1085.2554708634552,
#                                                                         'normalized_dist': 1.627069671459453,
#                                                                         'path_len': 601}},
#                               'normalized_dist': 9.577267735584371},
#     'joint_angles_indiv_joi': {   'accuracy': 0.9235199863422355,
#                                   'dist': 2040.4867643891553,
#                                   'joint_alignments': {   'L_HIP': {   'dist': 1144.5478023162545,
#                                                                        'normalized_dist': 1.715963721613575,
#                                                                        'path_len': 510},
#                                                           'R_HIP': {   'dist': 895.9389620729008,
#                                                                        'normalized_dist': 1.3432368246970028,
#                                                                        'path_len': 492}},
#                                   'normalized_dist': 3.059200546310578},
#     'joint_angles_indiv_norm': {   'accuracy': 0.9398635056329089,
#                                    'dist': 6417.766678855968,
#                                    'joint_alignments': {   'L_ELBOW': {   'dist': 1027.9010237804412,
#                                                                           'normalized_dist': 1.5410809951730753,
#                                                                           'path_len': 514},
#                                                            'L_HIP': {   'dist': 1257.5291411953554,
#                                                                         'normalized_dist': 1.8853510362748955,
#                                                                         'path_len': 514},
#                                                            'L_KNEE': {   'dist': 443.91777960810475,
#                                                                          'normalized_dist': 0.6655438974634255,
#                                                                          'path_len': 551},
#                                                            'L_SHOULDER': {   'dist': 381.3962644004043,
#                                                                              'normalized_dist': 0.5718084923544292,
#                                                                              'path_len': 523},
#                                                            'R_ELBOW': {   'dist': 763.0212686561906,
#                                                                           'normalized_dist': 1.1439599230227746,
#                                                                           'path_len': 564},
#                                                            'R_HIP': {   'dist': 1258.6471964948907,
#                                                                         'normalized_dist': 1.8870272811017852,
#                                                                         'path_len': 519},
#                                                            'R_KNEE': {   'dist': 628.871460609033,
#                                                                          'normalized_dist': 0.9428357730270359,
#                                                                          'path_len': 537},
#                                                            'R_SHOULDER': {   'dist': 656.4825441115479,
#                                                                              'normalized_dist': 0.9842317003171632,
#                                                                              'path_len': 542}},
#                                    'normalized_dist': 9.621839098734586},
#     'joint_angles_indiv_norm_joi': {   'accuracy': 0.905690542065583,
#                                        'dist': 2516.1763376902463,
#                                        'joint_alignments': {   'L_HIP': {   'dist': 1257.5291411953554,
#                                                                             'normalized_dist': 1.8853510362748955,
#                                                                             'path_len': 514},
#                                                                'R_HIP': {   'dist': 1258.6471964948907,
#                                                                             'normalized_dist': 1.8870272811017852,
#                                                                             'path_len': 519}},
#                                        'normalized_dist': 3.7723783173766807},
#     'pose_embedder_nonreal': {   'accuracy': -0.08756212176200817,
#                                  'dist': 41723.23323927768,
#                                  'normalized_dist': 62.55357307238033,
#                                  'path_len': 556},
#     'pose_embedder_nonreal_norm': {   'accuracy': -1.2748433851299565,
#                                       'dist': 29980.1609726277,
#                                       'normalized_dist': 44.94776757515397,
#                                       'path_len': 573},
#     'pose_embedder_real': {   'accuracy': 0.3605005211390806,
#                               'dist': 24533.75800702031,
#                               'normalized_dist': 36.782245887586676,
#                               'path_len': 556},
#     'pose_embedder_real_norm': {   'accuracy': 0.06297381206491182,
#                                    'dist': 12607.687358666612,
#                                    'normalized_dist': 18.902079998000918,
#                                    'path_len': 585}}
# 'LEG_RAISE_diff_angle_2023-01-10T14:39:58.102757'
# {   'joint_angles_agg': {   'accuracy': 0.6062866093131198,
#                             'dist': 38489.421073549405,
#                             'normalized_dist': 58.053425450300765,
#                             'path_len': 611},
#     'joint_angles_agg_joi': {   'accuracy': 0.6208773636072528,
#                                 'dist': 8371.02781155186,
#                                 'normalized_dist': 12.625984632808235,
#                                 'path_len': 552},
#     'joint_angles_agg_norm': {   'accuracy': 0.8434748257896748,
#                                  'dist': 14951.284640570262,
#                                  'normalized_dist': 22.55095722559617,
#                                  'path_len': 597},
#     'joint_angles_agg_norm_joi': {   'accuracy': 0.8547403893174611,
#                                      'dist': 2969.1064423510957,
#                                      'normalized_dist': 4.478290259956403,
#                                      'path_len': 511},
#     'joint_angles_indiv': {   'accuracy': 0.6208835870512234,
#                               'dist': 40216.669085606234,
#                               'joint_alignments': {   'L_ELBOW': {   'dist': 21074.697932155144,
#                                                                      'normalized_dist': 31.78687470913295,
#                                                                      'path_len': 661},
#                                                       'L_HIP': {   'dist': 2705.4139505627363,
#                                                                    'normalized_dist': 4.080564027998094,
#                                                                    'path_len': 546},
#                                                       'L_KNEE': {   'dist': 1949.1726402746604,
#                                                                     'normalized_dist': 2.9399285675334244,
#                                                                     'path_len': 591},
#                                                       'L_SHOULDER': {   'dist': 770.22079356064,
#                                                                         'normalized_dist': 1.1617206539376168,
#                                                                         'path_len': 552},
#                                                       'R_ELBOW': {   'dist': 6700.297702393775,
#                                                                      'normalized_dist': 10.106029717034351,
#                                                                      'path_len': 654},
#                                                       'R_HIP': {   'dist': 1288.2871756002967,
#                                                                    'normalized_dist': 1.943117911915983,
#                                                                    'path_len': 496},
#                                                       'R_KNEE': {   'dist': 821.9682781376887,
#                                                                     'normalized_dist': 1.239771158578716,
#                                                                     'path_len': 557},
#                                                       'R_SHOULDER': {   'dist': 4906.610612921288,
#                                                                         'normalized_dist': 7.400619325673134,
#                                                                         'path_len': 658}},
#                               'normalized_dist': 60.658626071804264},
#     'joint_angles_indiv_joi': {   'accuracy': 0.8494079515021481,
#                                   'dist': 3993.701126163033,
#                                   'joint_alignments': {   'L_HIP': {   'dist': 2705.4139505627363,
#                                                                        'normalized_dist': 4.080564027998094,
#                                                                        'path_len': 546},
#                                                           'R_HIP': {   'dist': 1288.2871756002967,
#                                                                        'normalized_dist': 1.943117911915983,
#                                                                        'path_len': 496}},
#                                   'normalized_dist': 6.023681939914077},
#     'joint_angles_indiv_norm': {   'accuracy': 0.9000465262815347,
#                                    'dist': 10603.064492054804,
#                                    'joint_alignments': {   'L_ELBOW': {   'dist': 2982.874149202976,
#                                                                           'normalized_dist': 4.499056031980356,
#                                                                           'path_len': 599},
#                                                            'L_HIP': {   'dist': 1010.5847116423636,
#                                                                         'normalized_dist': 1.5242605002147263,
#                                                                         'path_len': 513},
#                                                            'L_KNEE': {   'dist': 1139.2427384749249,
#                                                                          'normalized_dist': 1.718314839328695,
#                                                                          'path_len': 601},
#                                                            'L_SHOULDER': {   'dist': 786.9625281772344,
#                                                                              'normalized_dist': 1.1869721390305195,
#                                                                              'path_len': 552},
#                                                            'R_ELBOW': {   'dist': 1729.2933820747053,
#                                                                           'normalized_dist': 2.60828564415491,
#                                                                           'path_len': 606},
#                                                            'R_HIP': {   'dist': 1171.8039191554246,
#                                                                         'normalized_dist': 1.7674267257246223,
#                                                                         'path_len': 491},
#                                                            'R_KNEE': {   'dist': 824.6182448043917,
#                                                                          'normalized_dist': 1.2437680917109981,
#                                                                          'path_len': 550},
#                                                            'R_SHOULDER': {   'dist': 957.6848185227828,
#                                                                              'normalized_dist': 1.4444718228096272,
#                                                                              'path_len': 596}},
#                                    'normalized_dist': 15.992555794954452},
#     'joint_angles_indiv_norm_joi': {   'accuracy': 0.9177078193515162,
#                                        'dist': 2182.388630797788,
#                                        'joint_alignments': {   'L_HIP': {   'dist': 1010.5847116423636,
#                                                                             'normalized_dist': 1.5242605002147263,
#                                                                             'path_len': 513},
#                                                                'R_HIP': {   'dist': 1171.8039191554246,
#                                                                             'normalized_dist': 1.7674267257246223,
#                                                                             'path_len': 491}},
#                                        'normalized_dist': 3.2916872259393486},
#     'pose_embedder_nonreal': {   'accuracy': -5.614031637559388,
#                                  'dist': 296182.95076154696,
#                                  'normalized_dist': 446.73144911243884,
#                                  'path_len': 649},
#     'pose_embedder_nonreal_norm': {   'accuracy': -4.464255620067433,
#                                       'dist': 79177.06393477709,
#                                       'normalized_dist': 119.42241920780859,
#                                       'path_len': 630},
#     'pose_embedder_real': {   'accuracy': -4.519313696819782,
#                               'dist': 249826.2151728506,
#                               'normalized_dist': 376.8117875910266,
#                               'path_len': 656},
#     'pose_embedder_real_norm': {   'accuracy': -1.3840066775490936,
#                                    'dist': 36079.55705802798,
#                                    'normalized_dist': 54.418638096573126,
#                                    'path_len': 658}}
# 'LEG_RAISE_static_pose_2023-01-10T14:45:32.661028'
# {   'joint_angles_agg': {   'accuracy': 0.8064817331005715,
#                             'dist': 21333.453742993,
#                             'normalized_dist': 30.65151399855316,
#                             'path_len': 689},
#     'joint_angles_agg_joi': {   'accuracy': 0.5591464442490511,
#                                 'dist': 11938.314289735696,
#                                 'normalized_dist': 17.15275041628692,
#                                 'path_len': 677},
#     'joint_angles_agg_norm': {   'accuracy': 0.8249893068570507,
#                                  'dist': 19265.17710117585,
#                                  'normalized_dist': 27.679852156861852,
#                                  'path_len': 688},
#     'joint_angles_agg_norm_joi': {   'accuracy': 0.5427590321187392,
#                                      'dist': 12638.140352238046,
#                                      'normalized_dist': 18.158247632525928,
#                                      'path_len': 691},
#     'joint_angles_indiv': {   'accuracy': 0.6976867430694318,
#                               'dist': 33665.604291788084,
#                               'joint_alignments': {   'L_ELBOW': {   'dist': 4313.031935212697,
#                                                                      'normalized_dist': 6.196884964386059,
#                                                                      'path_len': 674},
#                                                       'L_HIP': {   'dist': 7133.60921097258,
#                                                                    'normalized_dist': 10.249438521512326,
#                                                                    'path_len': 667},
#                                                       'L_KNEE': {   'dist': 474.5670100156732,
#                                                                     'normalized_dist': 0.6818491523213696,
#                                                                     'path_len': 588},
#                                                       'L_SHOULDER': {   'dist': 992.31348451083,
#                                                                         'normalized_dist': 1.4257377651017673,
#                                                                         'path_len': 639},
#                                                       'R_ELBOW': {   'dist': 9975.097668208246,
#                                                                      'normalized_dist': 14.332036879609548,
#                                                                      'path_len': 693},
#                                                       'R_HIP': {   'dist': 8100.809597282577,
#                                                                    'normalized_dist': 11.639094248969219,
#                                                                    'path_len': 656},
#                                                       'R_KNEE': {   'dist': 1676.079545208293,
#                                                                     'normalized_dist': 2.4081602661038692,
#                                                                     'path_len': 604},
#                                                       'R_SHOULDER': {   'dist': 1000.0958403771849,
#                                                                         'normalized_dist': 1.43691931088676,
#                                                                         'path_len': 623}},
#                               'normalized_dist': 48.37012110889091},
#     'joint_angles_indiv_joi': {   'accuracy': 0.45278668073796136,
#                                   'dist': 15234.418808255155,
#                                   'joint_alignments': {   'L_HIP': {   'dist': 7133.60921097258,
#                                                                        'normalized_dist': 10.249438521512326,
#                                                                        'path_len': 667},
#                                                           'R_HIP': {   'dist': 8100.809597282577,
#                                                                        'normalized_dist': 11.639094248969219,
#                                                                        'path_len': 656}},
#                                   'normalized_dist': 21.888532770481547},
#     'joint_angles_indiv_norm': {   'accuracy': 0.7714635834504262,
#                                    'dist': 25449.815346960542,
#                                    'joint_alignments': {   'L_ELBOW': {   'dist': 3560.5791688344057,
#                                                                           'normalized_dist': 5.115774667865526,
#                                                                           'path_len': 656},
#                                                            'L_HIP': {   'dist': 7825.924096432201,
#                                                                         'normalized_dist': 11.244143816712931,
#                                                                         'path_len': 684},
#                                                            'L_KNEE': {   'dist': 443.78483004236136,
#                                                                          'normalized_dist': 0.6376218822447721,
#                                                                          'path_len': 580},
#                                                            'L_SHOULDER': {   'dist': 948.5593890328198,
#                                                                              'normalized_dist': 1.3628726853919826,
#                                                                              'path_len': 657},
#                                                            'R_ELBOW': {   'dist': 1582.7646147657535,
#                                                                           'normalized_dist': 2.2740870901806804,
#                                                                           'path_len': 633},
#                                                            'R_HIP': {   'dist': 8731.420567378529,
#                                                                         'normalized_dist': 12.545144493359956,
#                                                                         'path_len': 677},
#                                                            'R_KNEE': {   'dist': 1361.5589324928585,
#                                                                          'normalized_dist': 1.9562628340414634,
#                                                                          'path_len': 643},
#                                                            'R_SHOULDER': {   'dist': 995.22374798161,
#                                                                              'normalized_dist': 1.429919178134497,
#                                                                              'path_len': 622}},
#                                    'normalized_dist': 36.565826647931814},
#     'joint_angles_indiv_norm_joi': {   'accuracy': 0.40526779224817777,
#                                        'dist': 16557.34466381073,
#                                        'joint_alignments': {   'L_HIP': {   'dist': 7825.924096432201,
#                                                                             'normalized_dist': 11.244143816712931,
#                                                                             'path_len': 684},
#                                                                'R_HIP': {   'dist': 8731.420567378529,
#                                                                             'normalized_dist': 12.545144493359956,
#                                                                             'path_len': 677}},
#                                        'normalized_dist': 23.789288310072887},
#     'pose_embedder_nonreal': {   'accuracy': -1.8040980487389247,
#                                  'dist': 134083.55639654916,
#                                  'normalized_dist': 192.64878792607638,
#                                  'path_len': 693},
#     'pose_embedder_nonreal_norm': {   'accuracy': -3.0811217773050936,
#                                       'dist': 64673.53680495382,
#                                       'normalized_dist': 92.92174828297964,
#                                       'path_len': 689},
#     'pose_embedder_real': {   'accuracy': -0.6273182649144173,
#                               'dist': 77701.1925131336,
#                               'normalized_dist': 111.63964441542184,
#                               'path_len': 692},
#     'pose_embedder_real_norm': {   'accuracy': -0.6184898209935206,
#                                    'dist': 25685.433459167172,
#                                    'normalized_dist': 36.90435841834364,
#                                    'path_len': 690}}
# 'LEG_RAISE_pauses_2023-01-10T14:48:04.098655'
# {   'joint_angles_agg': {   'accuracy': 0.888365627408045,
#                             'dist': 13556.878207567006,
#                             'normalized_dist': 15.029798456282712,
#                             'path_len': 759},
#     'joint_angles_agg_joi': {   'accuracy': 0.8611762503007282,
#                                 'dist': 4109.182991098446,
#                                 'normalized_dist': 4.555635245120229,
#                                 'path_len': 740},
#     'joint_angles_agg_norm': {   'accuracy': 0.8582916646382531,
#                                  'dist': 17889.26025606693,
#                                  'normalized_dist': 19.832882767258237,
#                                  'path_len': 789},
#     'joint_angles_agg_norm_joi': {   'accuracy': 0.7945601900629844,
#                                      'dist': 6516.550771202137,
#                                      'normalized_dist': 7.224557396011239,
#                                      'path_len': 793},
#     'joint_angles_indiv': {   'accuracy': 0.9264804600649341,
#                               'dist': 10610.340003428708,
#                               'joint_alignments': {   'L_ELBOW': {   'dist': 2325.5508033666956,
#                                                                      'normalized_dist': 2.57821596825576,
#                                                                      'path_len': 750},
#                                                       'L_HIP': {   'dist': 1276.4969843528252,
#                                                                    'normalized_dist': 1.415185126776968,
#                                                                    'path_len': 718},
#                                                       'L_KNEE': {   'dist': 1271.9371277376715,
#                                                                     'normalized_dist': 1.4101298533677067,
#                                                                     'path_len': 786},
#                                                       'L_SHOULDER': {   'dist': 719.4388591904558,
#                                                                         'normalized_dist': 0.7976040567521683,
#                                                                         'path_len': 758},
#                                                       'R_ELBOW': {   'dist': 1767.6602070851618,
#                                                                      'normalized_dist': 1.9597119812474078,
#                                                                      'path_len': 792},
#                                                       'R_HIP': {   'dist': 1293.9759516230656,
#                                                                    'normalized_dist': 1.4345631392716913,
#                                                                    'path_len': 725},
#                                                       'R_KNEE': {   'dist': 849.5974464014787,
#                                                                     'normalized_dist': 0.9419040425737014,
#                                                                     'path_len': 760},
#                                                       'R_SHOULDER': {   'dist': 1105.6826236713541,
#                                                                         'normalized_dist': 1.2258122213651377,
#                                                                         'path_len': 775}},
#                               'normalized_dist': 11.763126389610541},
#     'joint_angles_indiv_joi': {   'accuracy': 0.9287562933487835,
#                                   'dist': 2570.472935975891,
#                                   'joint_alignments': {   'L_HIP': {   'dist': 1276.4969843528252,
#                                                                        'normalized_dist': 1.415185126776968,
#                                                                        'path_len': 718},
#                                                           'R_HIP': {   'dist': 1293.9759516230656,
#                                                                        'normalized_dist': 1.4345631392716913,
#                                                                        'path_len': 725}},
#                                   'normalized_dist': 2.8497482660486595},
#     'joint_angles_indiv_norm': {   'accuracy': 0.9101046740141039,
#                                    'dist': 12973.693446284533,
#                                    'joint_alignments': {   'L_ELBOW': {   'dist': 2258.456523505476,
#                                                                           'normalized_dist': 2.5038320659705944,
#                                                                           'path_len': 742},
#                                                            'L_HIP': {   'dist': 2356.0093115582654,
#                                                                         'normalized_dist': 2.6119837156965247,
#                                                                         'path_len': 755},
#                                                            'L_KNEE': {   'dist': 1133.9483168031409,
#                                                                          'normalized_dist': 1.2571489099813091,
#                                                                          'path_len': 809},
#                                                            'L_SHOULDER': {   'dist': 745.0476644324998,
#                                                                              'normalized_dist': 0.8259951933841462,
#                                                                              'path_len': 753},
#                                                            'R_ELBOW': {   'dist': 1466.3492312798687,
#                                                                           'normalized_dist': 1.625664336230453,
#                                                                           'path_len': 762},
#                                                            'R_HIP': {   'dist': 2763.894593206158,
#                                                                         'normalized_dist': 3.0641846931332126,
#                                                                         'path_len': 774},
#                                                            'R_KNEE': {   'dist': 1378.6673222870854,
#                                                                          'normalized_dist': 1.528456011404751,
#                                                                          'path_len': 799},
#                                                            'R_SHOULDER': {   'dist': 871.3204832120404,
#                                                                              'normalized_dist': 0.9659872319423951,
#                                                                              'path_len': 740}},
#                                    'normalized_dist': 14.383252157743385},
#     'joint_angles_indiv_norm_joi': {   'accuracy': 0.8580957897792566,
#                                        'dist': 5119.903904764424,
#                                        'joint_alignments': {   'L_HIP': {   'dist': 2356.0093115582654,
#                                                                             'normalized_dist': 2.6119837156965247,
#                                                                             'path_len': 755},
#                                                                'R_HIP': {   'dist': 2763.894593206158,
#                                                                             'normalized_dist': 3.0641846931332126,
#                                                                             'path_len': 774}},
#                                        'normalized_dist': 5.676168408829737},
#     'pose_embedder_nonreal': {   'accuracy': -0.16385013420422911,
#                                  'dist': 64646.05570437391,
#                                  'normalized_dist': 71.66968481637906,
#                                  'path_len': 805},
#     'pose_embedder_nonreal_norm': {   'accuracy': -1.5213722011525648,
#                                       'dist': 46915.17254684577,
#                                       'normalized_dist': 52.01238641557181,
#                                       'path_len': 809},
#     'pose_embedder_real': {   'accuracy': 0.301717725163853,
#                               'dist': 37967.00384739099,
#                               'normalized_dist': 42.09202200375941,
#                               'path_len': 788},
#     'pose_embedder_real_norm': {   'accuracy': -0.038564214436445754,
#                                    'dist': 19993.399692116018,
#                                    'normalized_dist': 22.165631587711772,
#                                    'path_len': 837}}
# 'LEG_RAISE_half_reps_2023-01-10T14:51:44.433881'
# {   'joint_angles_agg': {   'accuracy': 0.8658124392016359,
#                             'dist': 12731.715768548785,
#                             'normalized_dist': 19.03096527436291,
#                             'path_len': 593},
#     'joint_angles_agg_joi': {   'accuracy': 0.6848804225032743,
#                                 'dist': 7285.564631724299,
#                                 'normalized_dist': 10.890231138601344,
#                                 'path_len': 578},
#     'joint_angles_agg_norm': {   'accuracy': 0.8374378147335253,
#                                  'dist': 15631.979735224211,
#                                  'normalized_dist': 23.366187945028717,
#                                  'path_len': 601},
#     'joint_angles_agg_norm_joi': {   'accuracy': 0.6518463642353185,
#                                      'dist': 8397.465694644117,
#                                      'normalized_dist': 12.552265612323046,
#                                      'path_len': 603},
#     'joint_angles_indiv': {   'accuracy': 0.8696726469572047,
#                               'dist': 13950.23986970081,
#                               'joint_alignments': {   'L_ELBOW': {   'dist': 2111.026356733302,
#                                                                      'normalized_dist': 3.155495301544547,
#                                                                      'path_len': 570},
#                                                       'L_HIP': {   'dist': 3350.697612128013,
#                                                                    'normalized_dist': 5.008516610056821,
#                                                                    'path_len': 554},
#                                                       'L_KNEE': {   'dist': 482.5931318644967,
#                                                                     'normalized_dist': 0.7213649205747334,
#                                                                     'path_len': 564},
#                                                       'L_SHOULDER': {   'dist': 729.0628967554704,
#                                                                         'normalized_dist': 1.0897801147316448,
#                                                                         'path_len': 580},
#                                                       'R_ELBOW': {   'dist': 974.4959914303852,
#                                                                      'normalized_dist': 1.4566457271007252,
#                                                                      'path_len': 576},
#                                                       'R_HIP': {   'dist': 4271.4722554057225,
#                                                                    'normalized_dist': 6.3848613683194655,
#                                                                    'path_len': 567},
#                                                       'R_KNEE': {   'dist': 1067.1853196430877,
#                                                                     'normalized_dist': 1.595194797672777,
#                                                                     'path_len': 570},
#                                                       'R_SHOULDER': {   'dist': 963.7063057403316,
#                                                                         'normalized_dist': 1.4405176468465344,
#                                                                         'path_len': 602}},
#                               'normalized_dist': 20.85237648684725},
#     'joint_angles_indiv_joi': {   'accuracy': 0.7151655505405928,
#                                   'dist': 7622.169867533736,
#                                   'joint_alignments': {   'L_HIP': {   'dist': 3350.697612128013,
#                                                                        'normalized_dist': 5.008516610056821,
#                                                                        'path_len': 554},
#                                                           'R_HIP': {   'dist': 4271.4722554057225,
#                                                                        'normalized_dist': 6.3848613683194655,
#                                                                        'path_len': 567}},
#                                   'normalized_dist': 11.393377978376286},
#     'joint_angles_indiv_norm': {   'accuracy': 0.8636576960086113,
#                                    'dist': 14594.080219238245,
#                                    'joint_alignments': {   'L_ELBOW': {   'dist': 2071.2643643963565,
#                                                                           'normalized_dist': 3.096060335420563,
#                                                                           'path_len': 564},
#                                                            'L_HIP': {   'dist': 3873.927025289965,
#                                                                         'normalized_dist': 5.790623356188289,
#                                                                         'path_len': 590},
#                                                            'L_KNEE': {   'dist': 429.7675989499841,
#                                                                          'normalized_dist': 0.6424029879670914,
#                                                                          'path_len': 543},
#                                                            'L_SHOULDER': {   'dist': 643.6956378280962,
#                                                                              'normalized_dist': 0.9621758412976027,
#                                                                              'path_len': 589},
#                                                            'R_ELBOW': {   'dist': 805.519432626868,
#                                                                           'normalized_dist': 1.204064921714302,
#                                                                           'path_len': 564},
#                                                            'R_HIP': {   'dist': 4815.328444961571,
#                                                                         'normalized_dist': 7.197800366160794,
#                                                                         'path_len': 585},
#                                                            'R_KNEE': {   'dist': 1151.1559853126735,
#                                                                          'normalized_dist': 1.7207114877618437,
#                                                                          'path_len': 589},
#                                                            'R_SHOULDER': {   'dist': 803.4217298727315,
#                                                                              'normalized_dist': 1.2009293421117062,
#                                                                              'path_len': 583}},
#                                    'normalized_dist': 21.814768638622194},
#     'joint_angles_indiv_norm_joi': {   'accuracy': 0.6752894069412729,
#                                        'dist': 8689.255470251537,
#                                        'joint_alignments': {   'L_HIP': {   'dist': 3873.927025289965,
#                                                                             'normalized_dist': 5.790623356188289,
#                                                                             'path_len': 590},
#                                                                'R_HIP': {   'dist': 4815.328444961571,
#                                                                             'normalized_dist': 7.197800366160794,
#                                                                             'path_len': 585}},
#                                        'normalized_dist': 12.988423722349083},
#     'pose_embedder_nonreal': {   'accuracy': -0.4731475644097254,
#                                  'dist': 61598.19225822826,
#                                  'normalized_dist': 92.0750257970527,
#                                  'path_len': 606},
#     'pose_embedder_nonreal_norm': {   'accuracy': -1.9068957528954353,
#                                       'dist': 40650.03020848977,
#                                       'normalized_dist': 60.76237699325825,
#                                       'path_len': 608},
#     'pose_embedder_real': {   'accuracy': 0.15072240200189702,
#                               'dist': 35863.29440826389,
#                               'normalized_dist': 53.60731600637353,
#                               'path_len': 612},
#     'pose_embedder_real_norm': {   'accuracy': 0.0018845058813145021,
#                                    'dist': 14049.473695214618,
#                                    'normalized_dist': 21.00070806459584,
#                                    'path_len': 612}}

# %%
import json

pp = pprint.PrettyPrinter(indent=4, sort_dicts=True)
# Opening JSON file
f = open('./DTW_data_archive/SQUAT_DTW_pairs_2023-01-10T03:17:53.997716.json')
  
# returns JSON object as 
# a dictionary
data = json.load(f)

for pair in data:
    ex_data, ref_data = pair
    pp.pprint(ex_data['name'])
    pp.pprint(ex_data['analytics']['DTW'])
# Out:
# 'SQUAT_base_session_2023-01-10T03:09:55.626388'
# {   'joint_angles_agg': {   'accuracy': 0.8561540407251426,
#                             'dist': 11622.753509408478,
#                             'normalized_dist': 17.610232590012846,
#                             'path_len': 505},
#     'joint_angles_agg_joi': {   'accuracy': 0.8703210674761661,
#                                 'dist': 7889.666254750053,
#                                 'normalized_dist': 11.954039779924322,
#                                 'path_len': 507},
#     'joint_angles_agg_norm': {   'accuracy': 0.8233796957245536,
#                                  'dist': 15288.253538082641,
#                                  'normalized_dist': 23.164020512246427,
#                                  'path_len': 541},
#     'joint_angles_agg_norm_joi': {   'accuracy': 0.8339969525965738,
#                                      'dist': 10856.599300184074,
#                                      'normalized_dist': 16.449392879066778,
#                                      'path_len': 545},
#     'joint_angles_indiv': {   'accuracy': 0.9116859624959066,
#                               'dist': 9325.962360432268,
#                               'joint_alignments': {   'L_ELBOW': {   'dist': 1606.1846238731696,
#                                                                      'normalized_dist': 2.4336130664744995,
#                                                                      'path_len': 567},
#                                                       'L_HIP': {   'dist': 623.8694452296024,
#                                                                    'normalized_dist': 0.9452567351963673,
#                                                                    'path_len': 485},
#                                                       'L_KNEE': {   'dist': 1094.1577970097442,
#                                                                     'normalized_dist': 1.6578148439541578,
#                                                                     'path_len': 523},
#                                                       'L_SHOULDER': {   'dist': 2166.939615360288,
#                                                                         'normalized_dist': 3.2832418414549815,
#                                                                         'path_len': 543},
#                                                       'R_ELBOW': {   'dist': 1466.2295647775593,
#                                                                      'normalized_dist': 2.2215599466326656,
#                                                                      'path_len': 596},
#                                                       'R_HIP': {   'dist': 898.4150794049456,
#                                                                    'normalized_dist': 1.361234968795372,
#                                                                    'path_len': 493},
#                                                       'R_KNEE': {   'dist': 722.2980253307533,
#                                                                     'normalized_dist': 1.0943909474708382,
#                                                                     'path_len': 491},
#                                                       'R_SHOULDER': {   'dist': 747.8682094462059,
#                                                                         'normalized_dist': 1.1331336506760696,
#                                                                         'path_len': 486}},
#                               'normalized_dist': 14.130246000654951},
#     'joint_angles_indiv_joi': {   'accuracy': 0.9210410584371018,
#                                   'dist': 6253.548171781538,
#                                   'joint_alignments': {   'L_HIP': {   'dist': 623.8694452296024,
#                                                                        'normalized_dist': 0.9452567351963673,
#                                                                        'path_len': 485},
#                                                           'L_KNEE': {   'dist': 1094.1577970097442,
#                                                                         'normalized_dist': 1.6578148439541578,
#                                                                         'path_len': 523},
#                                                           'L_SHOULDER': {   'dist': 2166.939615360288,
#                                                                             'normalized_dist': 3.2832418414549815,
#                                                                             'path_len': 543},
#                                                           'R_HIP': {   'dist': 898.4150794049456,
#                                                                        'normalized_dist': 1.361234968795372,
#                                                                        'path_len': 493},
#                                                           'R_KNEE': {   'dist': 722.2980253307533,
#                                                                         'normalized_dist': 1.0943909474708382,
#                                                                         'path_len': 491},
#                                                           'R_SHOULDER': {   'dist': 747.8682094462059,
#                                                                             'normalized_dist': 1.1331336506760696,
#                                                                             'path_len': 486}},
#                                   'normalized_dist': 9.475072987547788},
#     'joint_angles_indiv_norm': {   'accuracy': 0.8504459773062509,
#                                    'dist': 15792.904796459907,
#                                    'joint_alignments': {   'L_ELBOW': {   'dist': 1357.30268026139,
#                                                                           'normalized_dist': 2.0565192125172573,
#                                                                           'path_len': 550},
#                                                            'L_HIP': {   'dist': 2078.1147447124877,
#                                                                         'normalized_dist': 3.1486587041098297,
#                                                                         'path_len': 543},
#                                                            'L_KNEE': {   'dist': 1810.756102635334,
#                                                                          'normalized_dist': 2.7435698524777785,
#                                                                          'path_len': 539},
#                                                            'L_SHOULDER': {   'dist': 2471.3176803270603,
#                                                                              'normalized_dist': 3.744420727768273,
#                                                                              'path_len': 562},
#                                                            'R_ELBOW': {   'dist': 1731.6487850639105,
#                                                                           'normalized_dist': 2.623710280399864,
#                                                                           'path_len': 591},
#                                                            'R_HIP': {   'dist': 1944.8958117740845,
#                                                                         'normalized_dist': 2.94681183602134,
#                                                                         'path_len': 538},
#                                                            'R_KNEE': {   'dist': 2582.090022242428,
#                                                                          'normalized_dist': 3.912257609458224,
#                                                                          'path_len': 548},
#                                                            'R_SHOULDER': {   'dist': 1816.778969443214,
#                                                                              'normalized_dist': 2.752695408247294,
#                                                                              'path_len': 532}},
#                                    'normalized_dist': 23.92864363099986},
#     'joint_angles_indiv_norm_joi': {   'accuracy': 0.8395965488493105,
#                                        'dist': 12703.953331134608,
#                                        'joint_alignments': {   'L_HIP': {   'dist': 2078.1147447124877,
#                                                                             'normalized_dist': 3.1486587041098297,
#                                                                             'path_len': 543},
#                                                                'L_KNEE': {   'dist': 1810.756102635334,
#                                                                              'normalized_dist': 2.7435698524777785,
#                                                                              'path_len': 539},
#                                                                'L_SHOULDER': {   'dist': 2471.3176803270603,
#                                                                                  'normalized_dist': 3.744420727768273,
#                                                                                  'path_len': 562},
#                                                                'R_HIP': {   'dist': 1944.8958117740845,
#                                                                             'normalized_dist': 2.94681183602134,
#                                                                             'path_len': 538},
#                                                                'R_KNEE': {   'dist': 2582.090022242428,
#                                                                              'normalized_dist': 3.912257609458224,
#                                                                              'path_len': 548},
#                                                                'R_SHOULDER': {   'dist': 1816.778969443214,
#                                                                                  'normalized_dist': 2.752695408247294,
#                                                                                  'path_len': 532}},
#                                        'normalized_dist': 19.24841413808274},
#     'pose_embedder_nonreal': {   'accuracy': 0.2965793370659696,
#                                  'dist': 28247.96698210479,
#                                  'normalized_dist': 42.79994997288605,
#                                  'path_len': 582},
#     'pose_embedder_nonreal_norm': {   'accuracy': -0.2629397604342978,
#                                       'dist': 16818.568789703542,
#                                       'normalized_dist': 25.482679984399308,
#                                       'path_len': 579},
#     'pose_embedder_real': {   'accuracy': 0.6252212020429633,
#                               'dist': 14429.733278941829,
#                               'normalized_dist': 21.863232240820953,
#                               'path_len': 558},
#     'pose_embedder_real_norm': {   'accuracy': 0.42205687609081577,
#                                    'dist': 7151.4682152522455,
#                                    'normalized_dist': 10.835557901897342,
#                                    'path_len': 538}}
# 'SQUAT_diff_angle_2023-01-10T03:11:03.044076'
# {   'joint_angles_agg': {   'accuracy': 0.7062036020294259,
#                             'dist': 25760.068174059936,
#                             'normalized_dist': 39.569997195176555,
#                             'path_len': 548},
#     'joint_angles_agg_joi': {   'accuracy': 0.7505934049321376,
#                                 'dist': 16311.191317438203,
#                                 'normalized_dist': 25.05559342156406,
#                                 'path_len': 545},
#     'joint_angles_agg_norm': {   'accuracy': 0.7758187969633027,
#                                  'dist': 19979.028814630463,
#                                  'normalized_dist': 30.689752403426212,
#                                  'path_len': 557},
#     'joint_angles_agg_norm_joi': {   'accuracy': 0.7728835552805289,
#                                      'dist': 15125.955218316776,
#                                      'normalized_dist': 23.234954252406723,
#                                      'path_len': 555},
#     'joint_angles_indiv': {   'accuracy': 0.7864863032636036,
#                               'dist': 22239.586652063055,
#                               'joint_alignments': {   'L_ELBOW': {   'dist': 6648.370894923736,
#                                                                      'normalized_dist': 10.212551297885923,
#                                                                      'path_len': 608},
#                                                       'L_HIP': {   'dist': 2413.70165926171,
#                                                                    'normalized_dist': 3.7076830403405685,
#                                                                    'path_len': 525},
#                                                       'L_KNEE': {   'dist': 2123.5228475786344,
#                                                                     'normalized_dist': 3.2619398580316963,
#                                                                     'path_len': 537},
#                                                       'L_SHOULDER': {   'dist': 4305.579632695891,
#                                                                         'normalized_dist': 6.613793598611199,
#                                                                         'path_len': 563},
#                                                       'R_ELBOW': {   'dist': 1718.219949431827,
#                                                                      'normalized_dist': 2.6393547610319925,
#                                                                      'path_len': 551},
#                                                       'R_HIP': {   'dist': 1648.7844482514035,
#                                                                    'normalized_dist': 2.5326950049944754,
#                                                                    'path_len': 530},
#                                                       'R_KNEE': {   'dist': 1051.7751279953209,
#                                                                     'normalized_dist': 1.6156299969206158,
#                                                                     'path_len': 518},
#                                                       'R_SHOULDER': {   'dist': 2329.6320919245327,
#                                                                         'normalized_dist': 3.578543920006963,
#                                                                         'path_len': 541}},
#                               'normalized_dist': 34.162191477823434},
#     'joint_angles_indiv_joi': {   'accuracy': 0.8224142881757874,
#                                   'dist': 13872.995807707492,
#                                   'joint_alignments': {   'L_HIP': {   'dist': 2413.70165926171,
#                                                                        'normalized_dist': 3.7076830403405685,
#                                                                        'path_len': 525},
#                                                           'L_KNEE': {   'dist': 2123.5228475786344,
#                                                                         'normalized_dist': 3.2619398580316963,
#                                                                         'path_len': 537},
#                                                           'L_SHOULDER': {   'dist': 4305.579632695891,
#                                                                             'normalized_dist': 6.613793598611199,
#                                                                             'path_len': 563},
#                                                           'R_HIP': {   'dist': 1648.7844482514035,
#                                                                        'normalized_dist': 2.5326950049944754,
#                                                                        'path_len': 530},
#                                                           'R_KNEE': {   'dist': 1051.7751279953209,
#                                                                         'normalized_dist': 1.6156299969206158,
#                                                                         'path_len': 518},
#                                                           'R_SHOULDER': {   'dist': 2329.6320919245327,
#                                                                             'normalized_dist': 3.578543920006963,
#                                                                             'path_len': 541}},
#                                   'normalized_dist': 21.310285418905515},
#     'joint_angles_indiv_norm': {   'accuracy': 0.8010114450154746,
#                                    'dist': 20726.647887188166,
#                                    'joint_alignments': {   'L_ELBOW': {   'dist': 3927.8739577051715,
#                                                                           'normalized_dist': 6.033600549470309,
#                                                                           'path_len': 607},
#                                                            'L_HIP': {   'dist': 2982.578693300387,
#                                                                         'normalized_dist': 4.581534091091224,
#                                                                         'path_len': 521},
#                                                            'L_KNEE': {   'dist': 2565.9997407576398,
#                                                                          'normalized_dist': 3.941627865987158,
#                                                                          'path_len': 528},
#                                                            'L_SHOULDER': {   'dist': 4604.462620909291,
#                                                                              'normalized_dist': 7.072907251780785,
#                                                                              'path_len': 560},
#                                                            'R_ELBOW': {   'dist': 1845.496081645943,
#                                                                           'normalized_dist': 2.834863412666579,
#                                                                           'path_len': 560},
#                                                            'R_HIP': {   'dist': 1616.5525284840985,
#                                                                         'normalized_dist': 2.4831836075024554,
#                                                                         'path_len': 530},
#                                                            'R_KNEE': {   'dist': 1724.4227223372275,
#                                                                          'normalized_dist': 2.648882830011102,
#                                                                          'path_len': 528},
#                                                            'R_SHOULDER': {   'dist': 1459.2615420484092,
#                                                                              'normalized_dist': 2.2415691890144536,
#                                                                              'path_len': 539}},
#                                    'normalized_dist': 31.838168797524066},
#     'joint_angles_indiv_norm_joi': {   'accuracy': 0.8085857930384401,
#                                        'dist': 14953.277847837053,
#                                        'joint_alignments': {   'L_HIP': {   'dist': 2982.578693300387,
#                                                                             'normalized_dist': 4.581534091091224,
#                                                                             'path_len': 521},
#                                                                'L_KNEE': {   'dist': 2565.9997407576398,
#                                                                              'normalized_dist': 3.941627865987158,
#                                                                              'path_len': 528},
#                                                                'L_SHOULDER': {   'dist': 4604.462620909291,
#                                                                                  'normalized_dist': 7.072907251780785,
#                                                                                  'path_len': 560},
#                                                                'R_HIP': {   'dist': 1616.5525284840985,
#                                                                             'normalized_dist': 2.4831836075024554,
#                                                                             'path_len': 530},
#                                                                'R_KNEE': {   'dist': 1724.4227223372275,
#                                                                              'normalized_dist': 2.648882830011102,
#                                                                              'path_len': 528},
#                                                                'R_SHOULDER': {   'dist': 1459.2615420484092,
#                                                                                  'normalized_dist': 2.2415691890144536,
#                                                                                  'path_len': 539}},
#                                        'normalized_dist': 22.969704835387176},
#     'pose_embedder_nonreal': {   'accuracy': -2.0228642652323137,
#                                  'dist': 130152.4438038425,
#                                  'normalized_dist': 199.92694900743857,
#                                  'path_len': 624},
#     'pose_embedder_nonreal_norm': {   'accuracy': -2.0563139620247153,
#                                       'dist': 42950.380108333324,
#                                       'normalized_dist': 65.97600631080388,
#                                       'path_len': 611},
#     'pose_embedder_real': {   'accuracy': -0.920727514083558,
#                               'dist': 85481.97801428875,
#                               'normalized_dist': 131.30872198815476,
#                               'path_len': 645},
#     'pose_embedder_real_norm': {   'accuracy': -0.24306534253388312,
#                                    'dist': 16496.720160767163,
#                                    'normalized_dist': 25.340583964312078,
#                                    'path_len': 577}}
# 'SQUAT_static_pose_2023-01-10T03:12:06.560951'
# {   'joint_angles_agg': {   'accuracy': 0.7494185489835326,
#                             'dist': 25940.191809224714,
#                             'normalized_dist': 39.72464289314657,
#                             'path_len': 647},
#     'joint_angles_agg_joi': {   'accuracy': 0.7002089936098876,
#                                 'dist': 23311.748656895143,
#                                 'normalized_dist': 35.69946195542901,
#                                 'path_len': 648},
#     'joint_angles_agg_norm': {   'accuracy': 0.707480908637486,
#                                  'dist': 30468.78855631946,
#                                  'normalized_dist': 46.65970682437896,
#                                  'path_len': 651},
#     'joint_angles_agg_norm_joi': {   'accuracy': 0.6749819969648269,
#                                      'dist': 25312.402076379283,
#                                      'normalized_dist': 38.763249734118354,
#                                      'path_len': 649},
#     'joint_angles_indiv': {   'accuracy': 0.41583000087762656,
#                               'dist': 61034.081508305586,
#                               'joint_alignments': {   'L_ELBOW': {   'dist': 7410.945233944427,
#                                                                      'normalized_dist': 11.349073865152262,
#                                                                      'path_len': 644},
#                                                       'L_HIP': {   'dist': 7217.367358470178,
#                                                                    'normalized_dist': 11.052629951715433,
#                                                                    'path_len': 639},
#                                                       'L_KNEE': {   'dist': 7071.353099152467,
#                                                                     'normalized_dist': 10.82902465413854,
#                                                                     'path_len': 650},
#                                                       'L_SHOULDER': {   'dist': 6438.267944008105,
#                                                                         'normalized_dist': 9.85952211946111,
#                                                                         'path_len': 632},
#                                                       'R_ELBOW': {   'dist': 3908.5231379853926,
#                                                                      'normalized_dist': 5.985487194464613,
#                                                                      'path_len': 643},
#                                                       'R_HIP': {   'dist': 9818.874608689452,
#                                                                    'normalized_dist': 15.036561422189052,
#                                                                    'path_len': 636},
#                                                       'R_KNEE': {   'dist': 10827.41979355285,
#                                                                     'normalized_dist': 16.581041031474502,
#                                                                     'path_len': 619},
#                                                       'R_SHOULDER': {   'dist': 8341.330332502717,
#                                                                         'normalized_dist': 12.773859620984252,
#                                                                         'path_len': 628}},
#                               'normalized_dist': 93.46719985957975},
#     'joint_angles_indiv_joi': {   'accuracy': 0.36556134333364254,
#                                   'dist': 49714.61313637577,
#                                   'joint_alignments': {   'L_HIP': {   'dist': 7217.367358470178,
#                                                                        'normalized_dist': 11.052629951715433,
#                                                                        'path_len': 639},
#                                                           'L_KNEE': {   'dist': 7071.353099152467,
#                                                                         'normalized_dist': 10.82902465413854,
#                                                                         'path_len': 650},
#                                                           'L_SHOULDER': {   'dist': 6438.267944008105,
#                                                                             'normalized_dist': 9.85952211946111,
#                                                                             'path_len': 632},
#                                                           'R_HIP': {   'dist': 9818.874608689452,
#                                                                        'normalized_dist': 15.036561422189052,
#                                                                        'path_len': 636},
#                                                           'R_KNEE': {   'dist': 10827.41979355285,
#                                                                         'normalized_dist': 16.581041031474502,
#                                                                         'path_len': 619},
#                                                           'R_SHOULDER': {   'dist': 8341.330332502717,
#                                                                             'normalized_dist': 12.773859620984252,
#                                                                             'path_len': 628}},
#                                   'normalized_dist': 76.13263879996289},
#     'joint_angles_indiv_norm': {   'accuracy': 0.3996886363316834,
#                                    'dist': 62720.53127606572,
#                                    'joint_alignments': {   'L_ELBOW': {   'dist': 6340.369780590183,
#                                                                           'normalized_dist': 9.7096015016695,
#                                                                           'path_len': 650},
#                                                            'L_HIP': {   'dist': 8117.009191565582,
#                                                                         'normalized_dist': 12.430335668553724,
#                                                                         'path_len': 649},
#                                                            'L_KNEE': {   'dist': 7465.777015241076,
#                                                                          'normalized_dist': 11.433042902359993,
#                                                                          'path_len': 649},
#                                                            'L_SHOULDER': {   'dist': 6946.0523290555275,
#                                                                              'normalized_dist': 10.63713986072822,
#                                                                              'path_len': 648},
#                                                            'R_ELBOW': {   'dist': 3679.5456897837967,
#                                                                           'normalized_dist': 5.634832603037974,
#                                                                           'path_len': 647},
#                                                            'R_HIP': {   'dist': 10340.991978663287,
#                                                                         'normalized_dist': 15.83612860438482,
#                                                                         'path_len': 646},
#                                                            'R_KNEE': {   'dist': 11237.48674502946,
#                                                                          'normalized_dist': 17.209014923475436,
#                                                                          'path_len': 650},
#                                                            'R_SHOULDER': {   'dist': 8593.298546136808,
#                                                                              'normalized_dist': 13.159722122720993,
#                                                                              'path_len': 649}},
#                                    'normalized_dist': 96.04981818693066},
#     'joint_angles_indiv_norm_joi': {   'accuracy': 0.3274551326481401,
#                                        'dist': 52700.61580569174,
#                                        'joint_alignments': {   'L_HIP': {   'dist': 8117.009191565582,
#                                                                             'normalized_dist': 12.430335668553724,
#                                                                             'path_len': 649},
#                                                                'L_KNEE': {   'dist': 7465.777015241076,
#                                                                              'normalized_dist': 11.433042902359993,
#                                                                              'path_len': 649},
#                                                                'L_SHOULDER': {   'dist': 6946.0523290555275,
#                                                                                  'normalized_dist': 10.63713986072822,
#                                                                                  'path_len': 648},
#                                                                'R_HIP': {   'dist': 10340.991978663287,
#                                                                             'normalized_dist': 15.83612860438482,
#                                                                             'path_len': 646},
#                                                                'R_KNEE': {   'dist': 11237.48674502946,
#                                                                              'normalized_dist': 17.209014923475436,
#                                                                              'path_len': 650},
#                                                                'R_SHOULDER': {   'dist': 8593.298546136808,
#                                                                                  'normalized_dist': 13.159722122720993,
#                                                                                  'path_len': 649}},
#                                        'normalized_dist': 80.70538408222319},
#     'pose_embedder_nonreal': {   'accuracy': 0.015717612241318846,
#                                  'dist': 44077.1496062215,
#                                  'normalized_dist': 67.49946340922129,
#                                  'path_len': 649},
#     'pose_embedder_nonreal_norm': {   'accuracy': -0.8950485372261034,
#                                       'dist': 27982.286700680645,
#                                       'normalized_dist': 42.851893875468065,
#                                       'path_len': 642},
#     'pose_embedder_real': {   'accuracy': 0.40314881678347925,
#                               'dist': 26562.861909051255,
#                               'normalized_dist': 40.678195879098396,
#                               'path_len': 645},
#     'pose_embedder_real_norm': {   'accuracy': -0.061813060135421205,
#                                    'dist': 15874.105249024547,
#                                    'normalized_dist': 24.309502678444943,
#                                    'path_len': 650}}
# 'SQUAT_pauses_2023-01-10T03:13:12.025017'
# {   'joint_angles_agg': {   'accuracy': 0.8850188123308589,
#                             'dist': 13117.053889295625,
#                             'normalized_dist': 15.32366108562573,
#                             'path_len': 713},
#     'joint_angles_agg_joi': {   'accuracy': 0.887729572983379,
#                                 'dist': 9673.219991752068,
#                                 'normalized_dist': 11.300490644570173,
#                                 'path_len': 718},
#     'joint_angles_agg_norm': {   'accuracy': 0.8768719956475146,
#                                  'dist': 14223.747062799115,
#                                  'normalized_dist': 16.61652694252233,
#                                  'path_len': 722},
#     'joint_angles_agg_norm_joi': {   'accuracy': 0.8863695511887969,
#                                      'dist': 9940.391662004049,
#                                      'normalized_dist': 11.612607081780432,
#                                      'path_len': 729},
#     'joint_angles_indiv': {   'accuracy': 0.9255855590185623,
#                               'dist': 10191.801836817705,
#                               'joint_alignments': {   'L_ELBOW': {   'dist': 1147.5107354716204,
#                                                                      'normalized_dist': 1.340549924616379,
#                                                                      'path_len': 698},
#                                                       'L_HIP': {   'dist': 1151.7083824385993,
#                                                                    'normalized_dist': 1.345453717802102,
#                                                                    'path_len': 730},
#                                                       'L_KNEE': {   'dist': 893.7703289119042,
#                                                                     'normalized_dist': 1.0441242160185797,
#                                                                     'path_len': 714},
#                                                       'L_SHOULDER': {   'dist': 828.7555691824471,
#                                                                         'normalized_dist': 0.9681723939047279,
#                                                                         'path_len': 702},
#                                                       'R_ELBOW': {   'dist': 1037.5946221527633,
#                                                                      'normalized_dist': 1.212143250178462,
#                                                                      'path_len': 749},
#                                                       'R_HIP': {   'dist': 2771.694823696449,
#                                                                    'normalized_dist': 3.2379612426360387,
#                                                                    'path_len': 723},
#                                                       'R_KNEE': {   'dist': 1375.7306487833328,
#                                                                     'normalized_dist': 1.607161972877725,
#                                                                     'path_len': 717},
#                                                       'R_SHOULDER': {   'dist': 985.0367261805899,
#                                                                         'normalized_dist': 1.1507438389960163,
#                                                                         'path_len': 697}},
#                               'normalized_dist': 11.90631055703003},
#     'joint_angles_indiv_joi': {   'accuracy': 0.9220531884813734,
#                                   'dist': 8006.696479193322,
#                                   'joint_alignments': {   'L_HIP': {   'dist': 1151.7083824385993,
#                                                                        'normalized_dist': 1.345453717802102,
#                                                                        'path_len': 730},
#                                                           'L_KNEE': {   'dist': 893.7703289119042,
#                                                                         'normalized_dist': 1.0441242160185797,
#                                                                         'path_len': 714},
#                                                           'L_SHOULDER': {   'dist': 828.7555691824471,
#                                                                             'normalized_dist': 0.9681723939047279,
#                                                                             'path_len': 702},
#                                                           'R_HIP': {   'dist': 2771.694823696449,
#                                                                        'normalized_dist': 3.2379612426360387,
#                                                                        'path_len': 723},
#                                                           'R_KNEE': {   'dist': 1375.7306487833328,
#                                                                         'normalized_dist': 1.607161972877725,
#                                                                         'path_len': 717},
#                                                           'R_SHOULDER': {   'dist': 985.0367261805899,
#                                                                             'normalized_dist': 1.1507438389960163,
#                                                                             'path_len': 697}},
#                                   'normalized_dist': 9.35361738223519},
#     'joint_angles_indiv_norm': {   'accuracy': 0.9160445466720363,
#                                    'dist': 11498.538887797911,
#                                    'joint_alignments': {   'L_ELBOW': {   'dist': 1445.6401153517736,
#                                                                           'normalized_dist': 1.6888319104576794,
#                                                                           'path_len': 731},
#                                                            'L_HIP': {   'dist': 1482.8200123379404,
#                                                                         'normalized_dist': 1.7322663695536686,
#                                                                         'path_len': 731},
#                                                            'L_KNEE': {   'dist': 1184.8781203039289,
#                                                                          'normalized_dist': 1.3842034115700104,
#                                                                          'path_len': 716},
#                                                            'L_SHOULDER': {   'dist': 1086.2755279954908,
#                                                                              'normalized_dist': 1.269013467284452,
#                                                                              'path_len': 725},
#                                                            'R_ELBOW': {   'dist': 1451.1920100409175,
#                                                                           'normalized_dist': 1.6953177687393897,
#                                                                           'path_len': 774},
#                                                            'R_HIP': {   'dist': 1234.1861700045922,
#                                                                         'normalized_dist': 1.4418062733698507,
#                                                                         'path_len': 703},
#                                                            'R_KNEE': {   'dist': 2144.1358480393446,
#                                                                          'normalized_dist': 2.5048315981768043,
#                                                                          'path_len': 717},
#                                                            'R_SHOULDER': {   'dist': 1469.4110837239243,
#                                                                              'normalized_dist': 1.7166017333223416,
#                                                                              'path_len': 721}},
#                                    'normalized_dist': 13.432872532474198},
#     'joint_angles_indiv_norm_joi': {   'accuracy': 0.9162606428893573,
#                                        'dist': 8601.706762405222,
#                                        'joint_alignments': {   'L_HIP': {   'dist': 1482.8200123379404,
#                                                                             'normalized_dist': 1.7322663695536686,
#                                                                             'path_len': 731},
#                                                                'L_KNEE': {   'dist': 1184.8781203039289,
#                                                                              'normalized_dist': 1.3842034115700104,
#                                                                              'path_len': 716},
#                                                                'L_SHOULDER': {   'dist': 1086.2755279954908,
#                                                                                  'normalized_dist': 1.269013467284452,
#                                                                                  'path_len': 725},
#                                                                'R_HIP': {   'dist': 1234.1861700045922,
#                                                                             'normalized_dist': 1.4418062733698507,
#                                                                             'path_len': 703},
#                                                                'R_KNEE': {   'dist': 2144.1358480393446,
#                                                                              'normalized_dist': 2.5048315981768043,
#                                                                              'path_len': 717},
#                                                                'R_SHOULDER': {   'dist': 1469.4110837239243,
#                                                                                  'normalized_dist': 1.7166017333223416,
#                                                                                  'path_len': 721}},
#                                        'normalized_dist': 10.048722853277129},
#     'pose_embedder_nonreal': {   'accuracy': 0.20156061883481058,
#                                  'dist': 43302.561398112884,
#                                  'normalized_dist': 50.58710443704776,
#                                  'path_len': 786},
#     'pose_embedder_nonreal_norm': {   'accuracy': -0.4468905765453175,
#                                       'dist': 26156.88784278625,
#                                       'normalized_dist': 30.557111965871787,
#                                       'path_len': 786},
#     'pose_embedder_real': {   'accuracy': 0.42140551424866834,
#                               'dist': 31060.109184102985,
#                               'normalized_dist': 36.28517428049414,
#                               'path_len': 778},
#     'pose_embedder_real_norm': {   'accuracy': 0.3013272562142095,
#                                    'dist': 12212.799561375617,
#                                    'normalized_dist': 14.267289207214507,
#                                    'path_len': 760}}
# 'SQUAT_half_reps_2023-01-10T03:15:41.009580'
# {   'joint_angles_agg': {   'accuracy': 0.8051192628256194,
#                             'dist': 16432.343758543775,
#                             'normalized_dist': 26.71925814397362,
#                             'path_len': 527},
#     'joint_angles_agg_joi': {   'accuracy': 0.7853621576131422,
#                                 'dist': 13676.72331689058,
#                                 'normalized_dist': 22.238574499009076,
#                                 'path_len': 531},
#     'joint_angles_agg_norm': {   'accuracy': 0.7779945735029973,
#                                  'dist': 19287.831454059593,
#                                  'normalized_dist': 31.362327567576575,
#                                  'path_len': 543},
#     'joint_angles_agg_norm_joi': {   'accuracy': 0.7635280924209553,
#                                      'dist': 15635.522529126434,
#                                      'normalized_dist': 25.42361386849827,
#                                      'path_len': 551},
#     'joint_angles_indiv': {   'accuracy': 0.6959419108742658,
#                               'dist': 29919.315969972246,
#                               'joint_alignments': {   'L_ELBOW': {   'dist': 3135.9474587638224,
#                                                                      'normalized_dist': 5.099101558965565,
#                                                                      'path_len': 527},
#                                                       'L_HIP': {   'dist': 3609.979352166018,
#                                                                    'normalized_dist': 5.8698851254732,
#                                                                    'path_len': 519},
#                                                       'L_KNEE': {   'dist': 3527.589039347203,
#                                                                     'normalized_dist': 5.735917137149924,
#                                                                     'path_len': 519},
#                                                       'L_SHOULDER': {   'dist': 3163.734467577862,
#                                                                         'normalized_dist': 5.144283687118475,
#                                                                         'path_len': 534},
#                                                       'R_ELBOW': {   'dist': 1768.9644671202861,
#                                                                      'normalized_dist': 2.8763649871874573,
#                                                                      'path_len': 538},
#                                                       'R_HIP': {   'dist': 5349.675967659966,
#                                                                    'normalized_dist': 8.698660110016204,
#                                                                    'path_len': 531},
#                                                       'R_KNEE': {   'dist': 5293.978547567972,
#                                                                     'normalized_dist': 8.608095199297516,
#                                                                     'path_len': 527},
#                                                       'R_SHOULDER': {   'dist': 4069.446669769117,
#                                                                         'normalized_dist': 6.616986454909133,
#                                                                         'path_len': 534}},
#                               'normalized_dist': 48.64929426011747},
#     'joint_angles_indiv_joi': {   'accuracy': 0.6610514357169629,
#                                   'dist': 25014.404044088136,
#                                   'joint_alignments': {   'L_HIP': {   'dist': 3609.979352166018,
#                                                                        'normalized_dist': 5.8698851254732,
#                                                                        'path_len': 519},
#                                                           'L_KNEE': {   'dist': 3527.589039347203,
#                                                                         'normalized_dist': 5.735917137149924,
#                                                                         'path_len': 519},
#                                                           'L_SHOULDER': {   'dist': 3163.734467577862,
#                                                                             'normalized_dist': 5.144283687118475,
#                                                                             'path_len': 534},
#                                                           'R_HIP': {   'dist': 5349.675967659966,
#                                                                        'normalized_dist': 8.698660110016204,
#                                                                        'path_len': 531},
#                                                           'R_KNEE': {   'dist': 5293.978547567972,
#                                                                         'normalized_dist': 8.608095199297516,
#                                                                         'path_len': 527},
#                                                           'R_SHOULDER': {   'dist': 4069.446669769117,
#                                                                             'normalized_dist': 6.616986454909133,
#                                                                             'path_len': 534}},
#                                   'normalized_dist': 40.67382771396445},
#     'joint_angles_indiv_norm': {   'accuracy': 0.6589051218899133,
#                                    'dist': 33563.73600603253,
#                                    'joint_alignments': {   'L_ELBOW': {   'dist': 3395.0222614882114,
#                                                                           'normalized_dist': 5.520361400793839,
#                                                                           'path_len': 547},
#                                                            'L_HIP': {   'dist': 4243.828786557955,
#                                                                         'normalized_dist': 6.900534612289357,
#                                                                         'path_len': 540},
#                                                            'L_KNEE': {   'dist': 4161.7907426449065,
#                                                                          'normalized_dist': 6.767139418934807,
#                                                                          'path_len': 549},
#                                                            'L_SHOULDER': {   'dist': 3492.491698149323,
#                                                                              'normalized_dist': 5.678848289673696,
#                                                                              'path_len': 550},
#                                                            'R_ELBOW': {   'dist': 1949.389964209202,
#                                                                           'normalized_dist': 3.1697397792019544,
#                                                                           'path_len': 565},
#                                                            'R_HIP': {   'dist': 5599.824937103174,
#                                                                         'normalized_dist': 9.105406401793779,
#                                                                         'path_len': 540},
#                                                            'R_KNEE': {   'dist': 6241.11225589295,
#                                                                          'normalized_dist': 10.148150009582032,
#                                                                          'path_len': 541},
#                                                            'R_SHOULDER': {   'dist': 4480.275359986811,
#                                                                              'normalized_dist': 7.285000585344409,
#                                                                              'path_len': 530}},
#                                    'normalized_dist': 54.57518049761387},
#     'joint_angles_indiv_norm_joi': {   'accuracy': 0.6176243390198494,
#                                        'dist': 28219.32378033512,
#                                        'joint_alignments': {   'L_HIP': {   'dist': 4243.828786557955,
#                                                                             'normalized_dist': 6.900534612289357,
#                                                                             'path_len': 540},
#                                                                'L_KNEE': {   'dist': 4161.7907426449065,
#                                                                              'normalized_dist': 6.767139418934807,
#                                                                              'path_len': 549},
#                                                                'L_SHOULDER': {   'dist': 3492.491698149323,
#                                                                                  'normalized_dist': 5.678848289673696,
#                                                                                  'path_len': 550},
#                                                                'R_HIP': {   'dist': 5599.824937103174,
#                                                                             'normalized_dist': 9.105406401793779,
#                                                                             'path_len': 540},
#                                                                'R_KNEE': {   'dist': 6241.11225589295,
#                                                                              'normalized_dist': 10.148150009582032,
#                                                                              'path_len': 541},
#                                                                'R_SHOULDER': {   'dist': 4480.275359986811,
#                                                                                  'normalized_dist': 7.285000585344409,
#                                                                                  'path_len': 530}},
#                                        'normalized_dist': 45.88507931761808},
#     'pose_embedder_nonreal': {   'accuracy': 0.21728180620957038,
#                                  'dist': 31000.336783263756,
#                                  'normalized_dist': 50.40705168010367,
#                                  'path_len': 574},
#     'pose_embedder_nonreal_norm': {   'accuracy': -0.5473999648497136,
#                                       'dist': 20464.36453513746,
#                                       'normalized_dist': 33.275389488028395,
#                                       'path_len': 575},
#     'pose_embedder_real': {   'accuracy': 0.46924824264032505,
#                               'dist': 20727.979131924745,
#                               'normalized_dist': 33.70403110882072,
#                               'path_len': 566},
#     'pose_embedder_real_norm': {   'accuracy': 0.1791425694828549,
#                                    'dist': 10289.447891532414,
#                                    'normalized_dist': 16.730809579727502,
#                                    'path_len': 545}}

# %%
import json

pp = pprint.PrettyPrinter(indent=4, sort_dicts=True)
# Opening JSON file
f = open('./DTW_data_archive/LEG_RAISE_DTW_pairs_2023-01-10T14:53:52.291618.json')
  
# returns JSON object as 
# a dictionary
data = json.load(f)

for pair in data:
    ex_data, ref_data = pair
    pp.pprint(ex_data['name'])
    pp.pprint(ex_data['analytics']['DTW'])
# Out:
# 'LEG_RAISE_base_session_2023-01-10T14:37:19.476495'
# {   'joint_angles_agg': {   'accuracy': 0.9040023482071047,
#                             'dist': 7879.48725916085,
#                             'normalized_dist': 11.81332422662796,
#                             'path_len': 513},
#     'joint_angles_agg_joi': {   'accuracy': 0.8687139738435261,
#                                 'dist': 2709.743579869622,
#                                 'normalized_dist': 4.06258407776555,
#                                 'path_len': 516},
#     'joint_angles_agg_norm': {   'accuracy': 0.9029807884890347,
#                                  'dist': 8134.090693079331,
#                                  'normalized_dist': 12.195038520358818,
#                                  'path_len': 524},
#     'joint_angles_agg_norm_joi': {   'accuracy': 0.8439787661164688,
#                                      'dist': 3357.5769531735923,
#                                      'normalized_dist': 5.033848505507635,
#                                      'path_len': 538},
#     'joint_angles_indiv': {   'accuracy': 0.9401420766525976,
#                               'dist': 6388.037579634774,
#                               'joint_alignments': {   'L_ELBOW': {   'dist': 1028.6296135588448,
#                                                                      'normalized_dist': 1.5421733336714314,
#                                                                      'path_len': 514},
#                                                       'L_HIP': {   'dist': 1144.5478023162545,
#                                                                    'normalized_dist': 1.715963721613575,
#                                                                    'path_len': 510},
#                                                       'L_KNEE': {   'dist': 437.94442013648734,
#                                                                     'normalized_dist': 0.6565883360367126,
#                                                                     'path_len': 544},
#                                                       'L_SHOULDER': {   'dist': 400.5288826243483,
#                                                                         'normalized_dist': 0.6004930773978235,
#                                                                         'path_len': 529},
#                                                       'R_ELBOW': {   'dist': 797.6514005025286,
#                                                                      'normalized_dist': 1.1958791611732065,
#                                                                      'path_len': 563},
#                                                       'R_HIP': {   'dist': 895.9389620729008,
#                                                                    'normalized_dist': 1.3432368246970028,
#                                                                    'path_len': 492},
#                                                       'R_KNEE': {   'dist': 597.541027559955,
#                                                                     'normalized_dist': 0.8958636095351649,
#                                                                     'path_len': 521},
#                                                       'R_SHOULDER': {   'dist': 1085.2554708634552,
#                                                                         'normalized_dist': 1.627069671459453,
#                                                                         'path_len': 601}},
#                               'normalized_dist': 9.577267735584371},
#     'joint_angles_indiv_joi': {   'accuracy': 0.9235199863422355,
#                                   'dist': 2040.4867643891553,
#                                   'joint_alignments': {   'L_HIP': {   'dist': 1144.5478023162545,
#                                                                        'normalized_dist': 1.715963721613575,
#                                                                        'path_len': 510},
#                                                           'R_HIP': {   'dist': 895.9389620729008,
#                                                                        'normalized_dist': 1.3432368246970028,
#                                                                        'path_len': 492}},
#                                   'normalized_dist': 3.059200546310578},
#     'joint_angles_indiv_norm': {   'accuracy': 0.9398635056329089,
#                                    'dist': 6417.766678855968,
#                                    'joint_alignments': {   'L_ELBOW': {   'dist': 1027.9010237804412,
#                                                                           'normalized_dist': 1.5410809951730753,
#                                                                           'path_len': 514},
#                                                            'L_HIP': {   'dist': 1257.5291411953554,
#                                                                         'normalized_dist': 1.8853510362748955,
#                                                                         'path_len': 514},
#                                                            'L_KNEE': {   'dist': 443.91777960810475,
#                                                                          'normalized_dist': 0.6655438974634255,
#                                                                          'path_len': 551},
#                                                            'L_SHOULDER': {   'dist': 381.3962644004043,
#                                                                              'normalized_dist': 0.5718084923544292,
#                                                                              'path_len': 523},
#                                                            'R_ELBOW': {   'dist': 763.0212686561906,
#                                                                           'normalized_dist': 1.1439599230227746,
#                                                                           'path_len': 564},
#                                                            'R_HIP': {   'dist': 1258.6471964948907,
#                                                                         'normalized_dist': 1.8870272811017852,
#                                                                         'path_len': 519},
#                                                            'R_KNEE': {   'dist': 628.871460609033,
#                                                                          'normalized_dist': 0.9428357730270359,
#                                                                          'path_len': 537},
#                                                            'R_SHOULDER': {   'dist': 656.4825441115479,
#                                                                              'normalized_dist': 0.9842317003171632,
#                                                                              'path_len': 542}},
#                                    'normalized_dist': 9.621839098734586},
#     'joint_angles_indiv_norm_joi': {   'accuracy': 0.905690542065583,
#                                        'dist': 2516.1763376902463,
#                                        'joint_alignments': {   'L_HIP': {   'dist': 1257.5291411953554,
#                                                                             'normalized_dist': 1.8853510362748955,
#                                                                             'path_len': 514},
#                                                                'R_HIP': {   'dist': 1258.6471964948907,
#                                                                             'normalized_dist': 1.8870272811017852,
#                                                                             'path_len': 519}},
#                                        'normalized_dist': 3.7723783173766807},
#     'pose_embedder_nonreal': {   'accuracy': -0.08756212176200817,
#                                  'dist': 41723.23323927768,
#                                  'normalized_dist': 62.55357307238033,
#                                  'path_len': 556},
#     'pose_embedder_nonreal_norm': {   'accuracy': -1.2748433851299565,
#                                       'dist': 29980.1609726277,
#                                       'normalized_dist': 44.94776757515397,
#                                       'path_len': 573},
#     'pose_embedder_real': {   'accuracy': 0.3605005211390806,
#                               'dist': 24533.75800702031,
#                               'normalized_dist': 36.782245887586676,
#                               'path_len': 556},
#     'pose_embedder_real_norm': {   'accuracy': 0.06297381206491182,
#                                    'dist': 12607.687358666612,
#                                    'normalized_dist': 18.902079998000918,
#                                    'path_len': 585}}
# 'LEG_RAISE_diff_angle_2023-01-10T14:39:58.102757'
# {   'joint_angles_agg': {   'accuracy': 0.6062866093131198,
#                             'dist': 38489.421073549405,
#                             'normalized_dist': 58.053425450300765,
#                             'path_len': 611},
#     'joint_angles_agg_joi': {   'accuracy': 0.6208773636072528,
#                                 'dist': 8371.02781155186,
#                                 'normalized_dist': 12.625984632808235,
#                                 'path_len': 552},
#     'joint_angles_agg_norm': {   'accuracy': 0.8434748257896748,
#                                  'dist': 14951.284640570262,
#                                  'normalized_dist': 22.55095722559617,
#                                  'path_len': 597},
#     'joint_angles_agg_norm_joi': {   'accuracy': 0.8547403893174611,
#                                      'dist': 2969.1064423510957,
#                                      'normalized_dist': 4.478290259956403,
#                                      'path_len': 511},
#     'joint_angles_indiv': {   'accuracy': 0.6208835870512234,
#                               'dist': 40216.669085606234,
#                               'joint_alignments': {   'L_ELBOW': {   'dist': 21074.697932155144,
#                                                                      'normalized_dist': 31.78687470913295,
#                                                                      'path_len': 661},
#                                                       'L_HIP': {   'dist': 2705.4139505627363,
#                                                                    'normalized_dist': 4.080564027998094,
#                                                                    'path_len': 546},
#                                                       'L_KNEE': {   'dist': 1949.1726402746604,
#                                                                     'normalized_dist': 2.9399285675334244,
#                                                                     'path_len': 591},
#                                                       'L_SHOULDER': {   'dist': 770.22079356064,
#                                                                         'normalized_dist': 1.1617206539376168,
#                                                                         'path_len': 552},
#                                                       'R_ELBOW': {   'dist': 6700.297702393775,
#                                                                      'normalized_dist': 10.106029717034351,
#                                                                      'path_len': 654},
#                                                       'R_HIP': {   'dist': 1288.2871756002967,
#                                                                    'normalized_dist': 1.943117911915983,
#                                                                    'path_len': 496},
#                                                       'R_KNEE': {   'dist': 821.9682781376887,
#                                                                     'normalized_dist': 1.239771158578716,
#                                                                     'path_len': 557},
#                                                       'R_SHOULDER': {   'dist': 4906.610612921288,
#                                                                         'normalized_dist': 7.400619325673134,
#                                                                         'path_len': 658}},
#                               'normalized_dist': 60.658626071804264},
#     'joint_angles_indiv_joi': {   'accuracy': 0.8494079515021481,
#                                   'dist': 3993.701126163033,
#                                   'joint_alignments': {   'L_HIP': {   'dist': 2705.4139505627363,
#                                                                        'normalized_dist': 4.080564027998094,
#                                                                        'path_len': 546},
#                                                           'R_HIP': {   'dist': 1288.2871756002967,
#                                                                        'normalized_dist': 1.943117911915983,
#                                                                        'path_len': 496}},
#                                   'normalized_dist': 6.023681939914077},
#     'joint_angles_indiv_norm': {   'accuracy': 0.9000465262815347,
#                                    'dist': 10603.064492054804,
#                                    'joint_alignments': {   'L_ELBOW': {   'dist': 2982.874149202976,
#                                                                           'normalized_dist': 4.499056031980356,
#                                                                           'path_len': 599},
#                                                            'L_HIP': {   'dist': 1010.5847116423636,
#                                                                         'normalized_dist': 1.5242605002147263,
#                                                                         'path_len': 513},
#                                                            'L_KNEE': {   'dist': 1139.2427384749249,
#                                                                          'normalized_dist': 1.718314839328695,
#                                                                          'path_len': 601},
#                                                            'L_SHOULDER': {   'dist': 786.9625281772344,
#                                                                              'normalized_dist': 1.1869721390305195,
#                                                                              'path_len': 552},
#                                                            'R_ELBOW': {   'dist': 1729.2933820747053,
#                                                                           'normalized_dist': 2.60828564415491,
#                                                                           'path_len': 606},
#                                                            'R_HIP': {   'dist': 1171.8039191554246,
#                                                                         'normalized_dist': 1.7674267257246223,
#                                                                         'path_len': 491},
#                                                            'R_KNEE': {   'dist': 824.6182448043917,
#                                                                          'normalized_dist': 1.2437680917109981,
#                                                                          'path_len': 550},
#                                                            'R_SHOULDER': {   'dist': 957.6848185227828,
#                                                                              'normalized_dist': 1.4444718228096272,
#                                                                              'path_len': 596}},
#                                    'normalized_dist': 15.992555794954452},
#     'joint_angles_indiv_norm_joi': {   'accuracy': 0.9177078193515162,
#                                        'dist': 2182.388630797788,
#                                        'joint_alignments': {   'L_HIP': {   'dist': 1010.5847116423636,
#                                                                             'normalized_dist': 1.5242605002147263,
#                                                                             'path_len': 513},
#                                                                'R_HIP': {   'dist': 1171.8039191554246,
#                                                                             'normalized_dist': 1.7674267257246223,
#                                                                             'path_len': 491}},
#                                        'normalized_dist': 3.2916872259393486},
#     'pose_embedder_nonreal': {   'accuracy': -5.614031637559388,
#                                  'dist': 296182.95076154696,
#                                  'normalized_dist': 446.73144911243884,
#                                  'path_len': 649},
#     'pose_embedder_nonreal_norm': {   'accuracy': -4.464255620067433,
#                                       'dist': 79177.06393477709,
#                                       'normalized_dist': 119.42241920780859,
#                                       'path_len': 630},
#     'pose_embedder_real': {   'accuracy': -4.519313696819782,
#                               'dist': 249826.2151728506,
#                               'normalized_dist': 376.8117875910266,
#                               'path_len': 656},
#     'pose_embedder_real_norm': {   'accuracy': -1.3840066775490936,
#                                    'dist': 36079.55705802798,
#                                    'normalized_dist': 54.418638096573126,
#                                    'path_len': 658}}
# 'LEG_RAISE_static_pose_2023-01-10T14:45:32.661028'
# {   'joint_angles_agg': {   'accuracy': 0.8064817331005715,
#                             'dist': 21333.453742993,
#                             'normalized_dist': 30.65151399855316,
#                             'path_len': 689},
#     'joint_angles_agg_joi': {   'accuracy': 0.5591464442490511,
#                                 'dist': 11938.314289735696,
#                                 'normalized_dist': 17.15275041628692,
#                                 'path_len': 677},
#     'joint_angles_agg_norm': {   'accuracy': 0.8249893068570507,
#                                  'dist': 19265.17710117585,
#                                  'normalized_dist': 27.679852156861852,
#                                  'path_len': 688},
#     'joint_angles_agg_norm_joi': {   'accuracy': 0.5427590321187392,
#                                      'dist': 12638.140352238046,
#                                      'normalized_dist': 18.158247632525928,
#                                      'path_len': 691},
#     'joint_angles_indiv': {   'accuracy': 0.6976867430694318,
#                               'dist': 33665.604291788084,
#                               'joint_alignments': {   'L_ELBOW': {   'dist': 4313.031935212697,
#                                                                      'normalized_dist': 6.196884964386059,
#                                                                      'path_len': 674},
#                                                       'L_HIP': {   'dist': 7133.60921097258,
#                                                                    'normalized_dist': 10.249438521512326,
#                                                                    'path_len': 667},
#                                                       'L_KNEE': {   'dist': 474.5670100156732,
#                                                                     'normalized_dist': 0.6818491523213696,
#                                                                     'path_len': 588},
#                                                       'L_SHOULDER': {   'dist': 992.31348451083,
#                                                                         'normalized_dist': 1.4257377651017673,
#                                                                         'path_len': 639},
#                                                       'R_ELBOW': {   'dist': 9975.097668208246,
#                                                                      'normalized_dist': 14.332036879609548,
#                                                                      'path_len': 693},
#                                                       'R_HIP': {   'dist': 8100.809597282577,
#                                                                    'normalized_dist': 11.639094248969219,
#                                                                    'path_len': 656},
#                                                       'R_KNEE': {   'dist': 1676.079545208293,
#                                                                     'normalized_dist': 2.4081602661038692,
#                                                                     'path_len': 604},
#                                                       'R_SHOULDER': {   'dist': 1000.0958403771849,
#                                                                         'normalized_dist': 1.43691931088676,
#                                                                         'path_len': 623}},
#                               'normalized_dist': 48.37012110889091},
#     'joint_angles_indiv_joi': {   'accuracy': 0.45278668073796136,
#                                   'dist': 15234.418808255155,
#                                   'joint_alignments': {   'L_HIP': {   'dist': 7133.60921097258,
#                                                                        'normalized_dist': 10.249438521512326,
#                                                                        'path_len': 667},
#                                                           'R_HIP': {   'dist': 8100.809597282577,
#                                                                        'normalized_dist': 11.639094248969219,
#                                                                        'path_len': 656}},
#                                   'normalized_dist': 21.888532770481547},
#     'joint_angles_indiv_norm': {   'accuracy': 0.7714635834504262,
#                                    'dist': 25449.815346960542,
#                                    'joint_alignments': {   'L_ELBOW': {   'dist': 3560.5791688344057,
#                                                                           'normalized_dist': 5.115774667865526,
#                                                                           'path_len': 656},
#                                                            'L_HIP': {   'dist': 7825.924096432201,
#                                                                         'normalized_dist': 11.244143816712931,
#                                                                         'path_len': 684},
#                                                            'L_KNEE': {   'dist': 443.78483004236136,
#                                                                          'normalized_dist': 0.6376218822447721,
#                                                                          'path_len': 580},
#                                                            'L_SHOULDER': {   'dist': 948.5593890328198,
#                                                                              'normalized_dist': 1.3628726853919826,
#                                                                              'path_len': 657},
#                                                            'R_ELBOW': {   'dist': 1582.7646147657535,
#                                                                           'normalized_dist': 2.2740870901806804,
#                                                                           'path_len': 633},
#                                                            'R_HIP': {   'dist': 8731.420567378529,
#                                                                         'normalized_dist': 12.545144493359956,
#                                                                         'path_len': 677},
#                                                            'R_KNEE': {   'dist': 1361.5589324928585,
#                                                                          'normalized_dist': 1.9562628340414634,
#                                                                          'path_len': 643},
#                                                            'R_SHOULDER': {   'dist': 995.22374798161,
#                                                                              'normalized_dist': 1.429919178134497,
#                                                                              'path_len': 622}},
#                                    'normalized_dist': 36.565826647931814},
#     'joint_angles_indiv_norm_joi': {   'accuracy': 0.40526779224817777,
#                                        'dist': 16557.34466381073,
#                                        'joint_alignments': {   'L_HIP': {   'dist': 7825.924096432201,
#                                                                             'normalized_dist': 11.244143816712931,
#                                                                             'path_len': 684},
#                                                                'R_HIP': {   'dist': 8731.420567378529,
#                                                                             'normalized_dist': 12.545144493359956,
#                                                                             'path_len': 677}},
#                                        'normalized_dist': 23.789288310072887},
#     'pose_embedder_nonreal': {   'accuracy': -1.8040980487389247,
#                                  'dist': 134083.55639654916,
#                                  'normalized_dist': 192.64878792607638,
#                                  'path_len': 693},
#     'pose_embedder_nonreal_norm': {   'accuracy': -3.0811217773050936,
#                                       'dist': 64673.53680495382,
#                                       'normalized_dist': 92.92174828297964,
#                                       'path_len': 689},
#     'pose_embedder_real': {   'accuracy': -0.6273182649144173,
#                               'dist': 77701.1925131336,
#                               'normalized_dist': 111.63964441542184,
#                               'path_len': 692},
#     'pose_embedder_real_norm': {   'accuracy': -0.6184898209935206,
#                                    'dist': 25685.433459167172,
#                                    'normalized_dist': 36.90435841834364,
#                                    'path_len': 690}}
# 'LEG_RAISE_pauses_2023-01-10T14:48:04.098655'
# {   'joint_angles_agg': {   'accuracy': 0.888365627408045,
#                             'dist': 13556.878207567006,
#                             'normalized_dist': 15.029798456282712,
#                             'path_len': 759},
#     'joint_angles_agg_joi': {   'accuracy': 0.8611762503007282,
#                                 'dist': 4109.182991098446,
#                                 'normalized_dist': 4.555635245120229,
#                                 'path_len': 740},
#     'joint_angles_agg_norm': {   'accuracy': 0.8582916646382531,
#                                  'dist': 17889.26025606693,
#                                  'normalized_dist': 19.832882767258237,
#                                  'path_len': 789},
#     'joint_angles_agg_norm_joi': {   'accuracy': 0.7945601900629844,
#                                      'dist': 6516.550771202137,
#                                      'normalized_dist': 7.224557396011239,
#                                      'path_len': 793},
#     'joint_angles_indiv': {   'accuracy': 0.9264804600649341,
#                               'dist': 10610.340003428708,
#                               'joint_alignments': {   'L_ELBOW': {   'dist': 2325.5508033666956,
#                                                                      'normalized_dist': 2.57821596825576,
#                                                                      'path_len': 750},
#                                                       'L_HIP': {   'dist': 1276.4969843528252,
#                                                                    'normalized_dist': 1.415185126776968,
#                                                                    'path_len': 718},
#                                                       'L_KNEE': {   'dist': 1271.9371277376715,
#                                                                     'normalized_dist': 1.4101298533677067,
#                                                                     'path_len': 786},
#                                                       'L_SHOULDER': {   'dist': 719.4388591904558,
#                                                                         'normalized_dist': 0.7976040567521683,
#                                                                         'path_len': 758},
#                                                       'R_ELBOW': {   'dist': 1767.6602070851618,
#                                                                      'normalized_dist': 1.9597119812474078,
#                                                                      'path_len': 792},
#                                                       'R_HIP': {   'dist': 1293.9759516230656,
#                                                                    'normalized_dist': 1.4345631392716913,
#                                                                    'path_len': 725},
#                                                       'R_KNEE': {   'dist': 849.5974464014787,
#                                                                     'normalized_dist': 0.9419040425737014,
#                                                                     'path_len': 760},
#                                                       'R_SHOULDER': {   'dist': 1105.6826236713541,
#                                                                         'normalized_dist': 1.2258122213651377,
#                                                                         'path_len': 775}},
#                               'normalized_dist': 11.763126389610541},
#     'joint_angles_indiv_joi': {   'accuracy': 0.9287562933487835,
#                                   'dist': 2570.472935975891,
#                                   'joint_alignments': {   'L_HIP': {   'dist': 1276.4969843528252,
#                                                                        'normalized_dist': 1.415185126776968,
#                                                                        'path_len': 718},
#                                                           'R_HIP': {   'dist': 1293.9759516230656,
#                                                                        'normalized_dist': 1.4345631392716913,
#                                                                        'path_len': 725}},
#                                   'normalized_dist': 2.8497482660486595},
#     'joint_angles_indiv_norm': {   'accuracy': 0.9101046740141039,
#                                    'dist': 12973.693446284533,
#                                    'joint_alignments': {   'L_ELBOW': {   'dist': 2258.456523505476,
#                                                                           'normalized_dist': 2.5038320659705944,
#                                                                           'path_len': 742},
#                                                            'L_HIP': {   'dist': 2356.0093115582654,
#                                                                         'normalized_dist': 2.6119837156965247,
#                                                                         'path_len': 755},
#                                                            'L_KNEE': {   'dist': 1133.9483168031409,
#                                                                          'normalized_dist': 1.2571489099813091,
#                                                                          'path_len': 809},
#                                                            'L_SHOULDER': {   'dist': 745.0476644324998,
#                                                                              'normalized_dist': 0.8259951933841462,
#                                                                              'path_len': 753},
#                                                            'R_ELBOW': {   'dist': 1466.3492312798687,
#                                                                           'normalized_dist': 1.625664336230453,
#                                                                           'path_len': 762},
#                                                            'R_HIP': {   'dist': 2763.894593206158,
#                                                                         'normalized_dist': 3.0641846931332126,
#                                                                         'path_len': 774},
#                                                            'R_KNEE': {   'dist': 1378.6673222870854,
#                                                                          'normalized_dist': 1.528456011404751,
#                                                                          'path_len': 799},
#                                                            'R_SHOULDER': {   'dist': 871.3204832120404,
#                                                                              'normalized_dist': 0.9659872319423951,
#                                                                              'path_len': 740}},
#                                    'normalized_dist': 14.383252157743385},
#     'joint_angles_indiv_norm_joi': {   'accuracy': 0.8580957897792566,
#                                        'dist': 5119.903904764424,
#                                        'joint_alignments': {   'L_HIP': {   'dist': 2356.0093115582654,
#                                                                             'normalized_dist': 2.6119837156965247,
#                                                                             'path_len': 755},
#                                                                'R_HIP': {   'dist': 2763.894593206158,
#                                                                             'normalized_dist': 3.0641846931332126,
#                                                                             'path_len': 774}},
#                                        'normalized_dist': 5.676168408829737},
#     'pose_embedder_nonreal': {   'accuracy': -0.16385013420422911,
#                                  'dist': 64646.05570437391,
#                                  'normalized_dist': 71.66968481637906,
#                                  'path_len': 805},
#     'pose_embedder_nonreal_norm': {   'accuracy': -1.5213722011525648,
#                                       'dist': 46915.17254684577,
#                                       'normalized_dist': 52.01238641557181,
#                                       'path_len': 809},
#     'pose_embedder_real': {   'accuracy': 0.301717725163853,
#                               'dist': 37967.00384739099,
#                               'normalized_dist': 42.09202200375941,
#                               'path_len': 788},
#     'pose_embedder_real_norm': {   'accuracy': -0.038564214436445754,
#                                    'dist': 19993.399692116018,
#                                    'normalized_dist': 22.165631587711772,
#                                    'path_len': 837}}
# 'LEG_RAISE_half_reps_2023-01-10T14:51:44.433881'
# {   'joint_angles_agg': {   'accuracy': 0.8658124392016359,
#                             'dist': 12731.715768548785,
#                             'normalized_dist': 19.03096527436291,
#                             'path_len': 593},
#     'joint_angles_agg_joi': {   'accuracy': 0.6848804225032743,
#                                 'dist': 7285.564631724299,
#                                 'normalized_dist': 10.890231138601344,
#                                 'path_len': 578},
#     'joint_angles_agg_norm': {   'accuracy': 0.8374378147335253,
#                                  'dist': 15631.979735224211,
#                                  'normalized_dist': 23.366187945028717,
#                                  'path_len': 601},
#     'joint_angles_agg_norm_joi': {   'accuracy': 0.6518463642353185,
#                                      'dist': 8397.465694644117,
#                                      'normalized_dist': 12.552265612323046,
#                                      'path_len': 603},
#     'joint_angles_indiv': {   'accuracy': 0.8696726469572047,
#                               'dist': 13950.23986970081,
#                               'joint_alignments': {   'L_ELBOW': {   'dist': 2111.026356733302,
#                                                                      'normalized_dist': 3.155495301544547,
#                                                                      'path_len': 570},
#                                                       'L_HIP': {   'dist': 3350.697612128013,
#                                                                    'normalized_dist': 5.008516610056821,
#                                                                    'path_len': 554},
#                                                       'L_KNEE': {   'dist': 482.5931318644967,
#                                                                     'normalized_dist': 0.7213649205747334,
#                                                                     'path_len': 564},
#                                                       'L_SHOULDER': {   'dist': 729.0628967554704,
#                                                                         'normalized_dist': 1.0897801147316448,
#                                                                         'path_len': 580},
#                                                       'R_ELBOW': {   'dist': 974.4959914303852,
#                                                                      'normalized_dist': 1.4566457271007252,
#                                                                      'path_len': 576},
#                                                       'R_HIP': {   'dist': 4271.4722554057225,
#                                                                    'normalized_dist': 6.3848613683194655,
#                                                                    'path_len': 567},
#                                                       'R_KNEE': {   'dist': 1067.1853196430877,
#                                                                     'normalized_dist': 1.595194797672777,
#                                                                     'path_len': 570},
#                                                       'R_SHOULDER': {   'dist': 963.7063057403316,
#                                                                         'normalized_dist': 1.4405176468465344,
#                                                                         'path_len': 602}},
#                               'normalized_dist': 20.85237648684725},
#     'joint_angles_indiv_joi': {   'accuracy': 0.7151655505405928,
#                                   'dist': 7622.169867533736,
#                                   'joint_alignments': {   'L_HIP': {   'dist': 3350.697612128013,
#                                                                        'normalized_dist': 5.008516610056821,
#                                                                        'path_len': 554},
#                                                           'R_HIP': {   'dist': 4271.4722554057225,
#                                                                        'normalized_dist': 6.3848613683194655,
#                                                                        'path_len': 567}},
#                                   'normalized_dist': 11.393377978376286},
#     'joint_angles_indiv_norm': {   'accuracy': 0.8636576960086113,
#                                    'dist': 14594.080219238245,
#                                    'joint_alignments': {   'L_ELBOW': {   'dist': 2071.2643643963565,
#                                                                           'normalized_dist': 3.096060335420563,
#                                                                           'path_len': 564},
#                                                            'L_HIP': {   'dist': 3873.927025289965,
#                                                                         'normalized_dist': 5.790623356188289,
#                                                                         'path_len': 590},
#                                                            'L_KNEE': {   'dist': 429.7675989499841,
#                                                                          'normalized_dist': 0.6424029879670914,
#                                                                          'path_len': 543},
#                                                            'L_SHOULDER': {   'dist': 643.6956378280962,
#                                                                              'normalized_dist': 0.9621758412976027,
#                                                                              'path_len': 589},
#                                                            'R_ELBOW': {   'dist': 805.519432626868,
#                                                                           'normalized_dist': 1.204064921714302,
#                                                                           'path_len': 564},
#                                                            'R_HIP': {   'dist': 4815.328444961571,
#                                                                         'normalized_dist': 7.197800366160794,
#                                                                         'path_len': 585},
#                                                            'R_KNEE': {   'dist': 1151.1559853126735,
#                                                                          'normalized_dist': 1.7207114877618437,
#                                                                          'path_len': 589},
#                                                            'R_SHOULDER': {   'dist': 803.4217298727315,
#                                                                              'normalized_dist': 1.2009293421117062,
#                                                                              'path_len': 583}},
#                                    'normalized_dist': 21.814768638622194},
#     'joint_angles_indiv_norm_joi': {   'accuracy': 0.6752894069412729,
#                                        'dist': 8689.255470251537,
#                                        'joint_alignments': {   'L_HIP': {   'dist': 3873.927025289965,
#                                                                             'normalized_dist': 5.790623356188289,
#                                                                             'path_len': 590},
#                                                                'R_HIP': {   'dist': 4815.328444961571,
#                                                                             'normalized_dist': 7.197800366160794,
#                                                                             'path_len': 585}},
#                                        'normalized_dist': 12.988423722349083},
#     'pose_embedder_nonreal': {   'accuracy': -0.4731475644097254,
#                                  'dist': 61598.19225822826,
#                                  'normalized_dist': 92.0750257970527,
#                                  'path_len': 606},
#     'pose_embedder_nonreal_norm': {   'accuracy': -1.9068957528954353,
#                                       'dist': 40650.03020848977,
#                                       'normalized_dist': 60.76237699325825,
#                                       'path_len': 608},
#     'pose_embedder_real': {   'accuracy': 0.15072240200189702,
#                               'dist': 35863.29440826389,
#                               'normalized_dist': 53.60731600637353,
#                               'path_len': 612},
#     'pose_embedder_real_norm': {   'accuracy': 0.0018845058813145021,
#                                    'dist': 14049.473695214618,
#                                    'normalized_dist': 21.00070806459584,
#                                    'path_len': 612}}
